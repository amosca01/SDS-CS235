# %% [markdown]
# # Introduction to Pandas: the Python Data Analysis library
# This is a short introduction to pandas, geared mainly for new users and adapted heavily from the "10 Minutes to Pandas" tutorial from http://pandas.pydata.org. You can see more complex recipes in the Pandas Cookbook: http://pandas.pydata.org/pandas-docs/stable/cookbook.html
# ## Initial setup
# Let's start by importing 2 useful libraries: `pandas` and `numpy`

# %%
import pandas, numpy

# %% [markdown]
# You can create a `Series` by passing a list of values. By default, `pandas` will create an integer index.

# %%
s = pandas.Series([1,3,5,"data wrangling is awesome",8])
s
# Out:
# 0                            1
# 1                            3
# 2                            5
# 3    data wrangling is awesome
# 4                            8
# dtype: object

# %% [markdown]
# You can also use `pandas` to create an series of `datetime` objects. Let's make one for the week beginning September 9th, 2024:

# %%
dates = pandas.date_range('20240909',
                          periods = 7)
dates
# Out:
# DatetimeIndex(['2024-09-09', '2024-09-10', '2024-09-11', '2024-09-12',
#                '2024-09-13', '2024-09-14', '2024-09-15'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Now we'll create a `DataFrame` using the `dates` array as our index, fill it with some random values using `numpy`, and give the columns some labels.

# %%
df = pandas.DataFrame(numpy.random.randn(7,4), 
                      index = dates, 
                      columns = ['dog','cat','mouse','duck'])
df
# Out:
#                  dog       cat     mouse      duck
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231
# 2024-09-13  0.248999  0.014043  0.707281  1.048916
# 2024-09-14 -0.705177 -1.468168  1.403105  0.215721
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365

# %% [markdown]
# It can also be useful to know how to create a `DataFrame` from a `dict` of objects. This comes in particularly handy when working with JSON-like structures.

# %%
df2 = pandas.DataFrame({ 'A' : 1.,
                     'B' : pandas.Timestamp('20130102'),
                     'C' : pandas.Series(1,index=list(range(5)),dtype='float32'),
                     'D' : numpy.array([3] * 5
                                    ,dtype='int32'),
                     'E' : pandas.Categorical(["test","train","blah","train","blah"]),
                     'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   blah  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# 4  1.0 2013-01-02  1.0  3   blah  foo

# %% [markdown]
# ## Exploring the data in a DataFrame
# We can access the data types of each column in a `DataFrame` as follows:

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# We can display the `index`, `columns`, and the underlying `numpy values` separately:

# %%
df2.index
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.values
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'blah', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'blah', 'foo']],
#       dtype=object)

# %% [markdown]
# To get a quick statistical summary of your data, use the `.describe()` method:

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  5.0                    5  5.0  5.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %% [markdown]
# ## Some basic data transformations
# `DataFrames` have a built-in transpose:

# %%
df.T
# Out:
#        2024-09-09  2024-09-10  2024-09-11  2024-09-12  2024-09-13  2024-09-14  \
# dog     -2.105560    0.003013   -0.393719   -0.418953    0.248999   -0.705177
# cat     -0.042539    0.470142   -1.855561   -1.248454    0.014043   -1.468168
# mouse   -0.528332    0.581258   -1.684294    0.590280    0.707281    1.403105
# duck     1.039608   -2.682506   -2.943739   -1.503231    1.048916    0.215721
#
#        2024-09-15
# dog      0.136218
# cat     -3.372879
# mouse    2.391618
# duck    -0.167365

# %% [markdown]
# We can also sort a `DataFrame` along a given data dimension. For example, we might want to `sort` by the values in the `duck` column:

# %%
df.sort_values(by = "duck")
# Out:
#                  dog       cat     mouse      duck
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365
# 2024-09-14 -0.705177 -1.468168  1.403105  0.215721
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608
# 2024-09-13  0.248999  0.014043  0.707281  1.048916

# %% [markdown]
# We can also sort the rows `(axis=0)` and columns `(axis=1)` by their index/header values:

# %%
df.sort_index(axis = 0, 
              ascending = False)
# Out:
#                  dog       cat     mouse      duck
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365
# 2024-09-14 -0.705177 -1.468168  1.403105  0.215721
# 2024-09-13  0.248999  0.014043  0.707281  1.048916
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608

# %%
df.sort_index(axis = 1)
# Out:
#                  cat       dog      duck     mouse
# 2024-09-09 -0.042539 -2.105560  1.039608 -0.528332
# 2024-09-10  0.470142  0.003013 -2.682506  0.581258
# 2024-09-11 -1.855561 -0.393719 -2.943739 -1.684294
# 2024-09-12 -1.248454 -0.418953 -1.503231  0.590280
# 2024-09-13  0.014043  0.248999  1.048916  0.707281
# 2024-09-14 -1.468168 -0.705177  0.215721  1.403105
# 2024-09-15 -3.372879  0.136218 -0.167365  2.391618

# %% [markdown]
# ## Selection
# To see only only the first few rows of a `DataFrame`, use the `.head()` function:

# %%
df.head()
# Out:
#                  dog       cat     mouse      duck
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231
# 2024-09-13  0.248999  0.014043  0.707281  1.048916

# %% [markdown]
# To view only the last few rows, use the `.tail()` function. Note that by default, both `.head()` and `.tail()`$ return 5 rows. You can also specify the number you want by passing in an integer.

# %%
df.tail(3)
# Out:
#                  dog       cat     mouse      duck
# 2024-09-13  0.248999  0.014043  0.707281  1.048916
# 2024-09-14 -0.705177 -1.468168  1.403105  0.215721
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365

# %% [markdown]
# Selecting a single column via indexing yields a `Series`:

# %%
df2['A'] # a lot like df$A in R
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: A, dtype: float64

# %% [markdown]
# We can also select a subset of the rows using slicing. You can select either by integer indexing:

# %%
df[2:5]
# Out:
#                  dog       cat     mouse      duck
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231
# 2024-09-13  0.248999  0.014043  0.707281  1.048916

# %% [markdown]
# To select more than one column at a time, try `.loc[]`:

# %%
df.loc[:, ['cat', 'dog']]
# Out:
#                  cat       dog
# 2024-09-09 -0.042539 -2.105560
# 2024-09-10  0.470142  0.003013
# 2024-09-11 -1.855561 -0.393719
# 2024-09-12 -1.248454 -0.418953
# 2024-09-13  0.014043  0.248999
# 2024-09-14 -1.468168 -0.705177
# 2024-09-15 -3.372879  0.136218

# %% [markdown]
# And of course, you might want to do both at the same time:

# %%
df.loc['20240909':'20240911', ['cat', 'duck']]
# Out:
#                  cat      duck
# 2024-09-09 -0.042539  1.039608
# 2024-09-10  0.470142 -2.682506
# 2024-09-11 -1.855561 -2.943739

# %% [markdown]
# ## Boolean Indexing
# Sometimes it's useful to be able to select all rows that meet some criteria. For example, we might want all rows where the value in the `cat` column is greater than 0:

# %%
df[df['cat'] > 0]
# Out:
#                  dog       cat     mouse      duck
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506
# 2024-09-13  0.248999  0.014043  0.707281  1.048916

# %% [markdown]
# Or perhaps we'd like to eliminate all negative values:

# %%
nonneg = df[df > 0]
nonneg
# Out:
#                  dog       cat     mouse      duck
# 2024-09-09       NaN       NaN       NaN  1.039608
# 2024-09-10  0.003013  0.470142  0.581258       NaN
# 2024-09-11       NaN       NaN       NaN       NaN
# 2024-09-12       NaN       NaN  0.590280       NaN
# 2024-09-13  0.248999  0.014043  0.707281  1.048916
# 2024-09-14       NaN       NaN  1.403105  0.215721
# 2024-09-15  0.136218       NaN  2.391618       NaN

# %% [markdown]
# And then maybe we'd like to drop all the rows with missing values:

# %%
nonneg.dropna()
# Out:
#                  dog       cat     mouse      duck
# 2024-09-13  0.248999  0.014043  0.707281  1.048916

# %% [markdown]
# Oops... maybe not. How about we set them to 0 instead?

# %%
nonneg.fillna(value = 0)
# Out:
#                  dog       cat     mouse      duck
# 2024-09-09  0.000000  0.000000  0.000000  1.039608
# 2024-09-10  0.003013  0.470142  0.581258  0.000000
# 2024-09-11  0.000000  0.000000  0.000000  0.000000
# 2024-09-12  0.000000  0.000000  0.590280  0.000000
# 2024-09-13  0.248999  0.014043  0.707281  1.048916
# 2024-09-14  0.000000  0.000000  1.403105  0.215721
# 2024-09-15  0.136218  0.000000  2.391618  0.000000

# %% [markdown]
# But what if your values aren't numeric? No problem, we can also do filtering. First, let's copy the `DataFrame` and add a new column of nominal values:

# %%
df3 = df.copy()
df3['color'] = ['blue', 'green','red','blue','green','red','blue']
df3
# Out:
#                  dog       cat     mouse      duck  color
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608   blue
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506  green
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739    red
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231   blue
# 2024-09-13  0.248999  0.014043  0.707281  1.048916  green
# 2024-09-14 -0.705177 -1.468168  1.403105  0.215721    red
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365   blue

# %% [markdown]
# Now we can use the `.isin()` function to select only the rows with `green` or `blue` in the `color` column:

# %%
df3[df3['color'].isin(['green', 'blue'])]
# Out:
#                  dog       cat     mouse      duck  color
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608   blue
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506  green
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231   blue
# 2024-09-13  0.248999  0.014043  0.707281  1.048916  green
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365   blue

# %%
df3 # Note that none of the filtering operations change the original DataFrame
# Out:
#                  dog       cat     mouse      duck  color
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608   blue
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506  green
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739    red
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231   blue
# 2024-09-13  0.248999  0.014043  0.707281  1.048916  green
# 2024-09-14 -0.705177 -1.468168  1.403105  0.215721    red
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365   blue

# %% [markdown]
# ## Prefer something more like `dplyr`?
# The `dfply` module provides dplyr-style piping operations for `pandas DataFrames`, along with many familiar verbs. Note that `>>` is the `dfply` equivalent of `%>%`, and `X` represents the piped `DataFrame`.
#
# ### `select()`

# %%
from dfply import *

df2 >> select("A")
# Out:
#      A
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %% [markdown]
# Just be careful about python and spacing:

# %%
# Broken
# df2 >> 
#    select(X.A)
    
# If you want to indent, you need parens
(
df2 >> 
   select('A')
)
# Out:
#      A
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %% [markdown]
# ### Dropping columns with `drop()` or `select()`
#
# `drop()` is a helper function that does the opposite of `select()`:

# %%
(df2 >> 
   drop(X.E, X.F))
# Out:
#      A          B    C  D
# 0  1.0 2013-01-02  1.0  3
# 1  1.0 2013-01-02  1.0  3
# 2  1.0 2013-01-02  1.0  3
# 3  1.0 2013-01-02  1.0  3
# 4  1.0 2013-01-02  1.0  3

# %% [markdown]
# You can also use `select()` along with the `~` (which means "not") to drop unwanted columns:

# %%
(df2 >> 
   select(~X.E, ~X.F))
# Out:
#      A          B    C  D
# 0  1.0 2013-01-02  1.0  3
# 1  1.0 2013-01-02  1.0  3
# 2  1.0 2013-01-02  1.0  3
# 3  1.0 2013-01-02  1.0  3
# 4  1.0 2013-01-02  1.0  3

# %% [markdown]
# ### Filtering with `mask()`
# `mask()` keeps all the rows where the criteria is/are true:

# %%
# this is just like filter() in R
(df3 >>
   mask(X.color.isin(['green','blue']), X.cat > 0))
# Out:
#                  dog       cat     mouse      duck  color
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506  green
# 2024-09-13  0.248999  0.014043  0.707281  1.048916  green

# %% [markdown]
# ### Add new columns with `mutate()`

# %%
(df3 >>
   mutate(platypus = (X.cat + X.duck)/2))
# Out:
#                  dog       cat     mouse      duck  color  platypus
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608   blue  0.498534
# 2024-09-10  0.003013  0.470142  0.581258 -2.682506  green -1.106182
# 2024-09-11 -0.393719 -1.855561 -1.684294 -2.943739    red -2.399650
# 2024-09-12 -0.418953 -1.248454  0.590280 -1.503231   blue -1.375843
# 2024-09-13  0.248999  0.014043  0.707281  1.048916  green  0.531479
# 2024-09-14 -0.705177 -1.468168  1.403105  0.215721    red -0.626224
# 2024-09-15  0.136218 -3.372879  2.391618 -0.167365   blue -1.770122

# %% [markdown]
# ## Basic Math
# Helper methods on the `DataFrame` object make it straightforward to calculate things like the `.mean()` across all numeric columns:

# %%
df.mean(axis = 0)
# Out:
# dog     -0.462168
# cat     -1.071917
# mouse    0.494417
# duck    -0.713228
# dtype: float64

# %% [markdown]
# We can also perform the same operation on individual rows:

# %%
df.mean(axis = 1)
# Out:
# 2024-09-09   -0.409206
# 2024-09-10   -0.407023
# 2024-09-11   -1.719328
# 2024-09-12   -0.645090
# 2024-09-13    0.504810
# 2024-09-14   -0.138630
# 2024-09-15   -0.253102
# Freq: D, dtype: float64

# %% [markdown]
# `.median()` also behaves as expected:

# %%
df.median(axis = 0)
# Out:
# dog     -0.393719
# cat     -1.248454
# mouse    0.590280
# duck    -0.167365
# dtype: float64

# %% [markdown]
# No helper function for what you need? No problem. You can also use the `.apply()` function to evaluate functions to the data. The defauls is to apply to `axis=0` aka apply the function within each column. For example, we might want to perform a cumulative summation (thanks, `numpy`!):

# %%
df.apply(numpy.cumsum)
# Out:
#                  dog       cat     mouse      duck
# 2024-09-09 -2.105560 -0.042539 -0.528332  1.039608
# 2024-09-10 -2.102546  0.427603  0.052925 -1.642898
# 2024-09-11 -2.496265 -1.427958 -1.631368 -4.586637
# 2024-09-12 -2.915218 -2.676412 -1.041088 -6.089868
# 2024-09-13 -2.666220 -2.662369 -0.333807 -5.040952
# 2024-09-14 -3.371397 -4.130537  1.069298 -4.825231
# 2024-09-15 -3.235179 -7.503416  3.460916 -4.992595

# %% [markdown]
# Or apply your own function, such as finding the spread (`max` value - `min` value):

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# dog      2.354558
# cat      3.843022
# mouse    4.075912
# duck     3.992654
# dtype: float64

# %% [markdown]
# ## Combining DataFrames
# Combining `DataFrame` objects can be done using simple concatenation (provided they have the same columns):

# %%
frame_one = pandas.DataFrame(numpy.random.randn(5, 4))
frame_one
# Out:
#           0         1         2         3
# 0  1.836785  0.166022 -0.157606  1.879076
# 1 -1.523137  0.596956  3.116997  0.622276
# 2  0.603631 -0.559675 -0.273719  0.549281
# 3  1.191431 -2.194677  0.106545  0.863456
# 4 -1.202323 -0.702567 -1.078121 -0.915032

# %%
frame_two = pandas.DataFrame(numpy.random.randn(5, 4))
frame_two
# Out:
#           0         1         2         3
# 0 -0.261409 -1.106251 -1.270702 -1.476162
# 1 -0.473184 -0.168612 -0.841774 -0.224236
# 2 -0.000337  0.661093 -0.204945  0.854811
# 3 -0.598379  1.457130  0.969852  0.795908
# 4  1.303509 -0.756101 -1.562320 -0.827245

# %%
pandas.concat([frame_one, frame_two])
# Out:
#           0         1         2         3
# 0  1.836785  0.166022 -0.157606  1.879076
# 1 -1.523137  0.596956  3.116997  0.622276
# 2  0.603631 -0.559675 -0.273719  0.549281
# 3  1.191431 -2.194677  0.106545  0.863456
# 4 -1.202323 -0.702567 -1.078121 -0.915032
# 0 -0.261409 -1.106251 -1.270702 -1.476162
# 1 -0.473184 -0.168612 -0.841774 -0.224236
# 2 -0.000337  0.661093 -0.204945  0.854811
# 3 -0.598379  1.457130  0.969852  0.795908
# 4  1.303509 -0.756101 -1.562320 -0.827245

# %% [markdown]
# If your `DataFrames` do not have an identical structure, but do share a common key, you can also perform a SQL-style join using the `.merge()` function:

# %%
left = pandas.DataFrame({'blah': ['foo', 'bar'], 
                         'lval': [1, 2]})
left
# Out:
#   blah  lval
# 0  foo     1
# 1  bar     2

# %%
right = pandas.DataFrame({'blah': ['foo', 'foo', 'bar'], 
                          'rval': [3, 4, 5]})
right
# Out:
#   blah  rval
# 0  foo     3
# 1  foo     4
# 2  bar     5

# %%
joined_data = pandas.merge(left, right, on = "blah")
joined_data
# Out:
#   blah  lval  rval
# 0  foo     1     3
# 1  foo     1     4
# 2  bar     2     5

# %% [markdown]
# Don't worry, `dfply` lets us do this using `join`s too:

# %%
left >> inner_join(right, by = "blah")
# Out:
#   blah  lval  rval
# 0  foo     1     3
# 1  foo     1     4
# 2  bar     2     5

# %% [markdown]
# ## Grouping
# Sometimes when working with multivariate data, it's helpful to be able to condense the data along a certain dimension in order to perform a calculation more efficiently. Let's start by creating a somewhat messy `DataFrame`:

# %%
foo_bar = pandas.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar','foo', 'bar', 'foo', 'foo'],
                            'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                            'C' : numpy.random.randn(8),
                            'D' : numpy.random.randn(8)})
foo_bar
# Out:
#      A      B         C         D
# 0  foo    one  0.159290 -0.821985
# 1  bar    one  1.382790 -0.927720
# 2  foo    two -0.294717  0.238600
# 3  bar  three  0.538998 -0.158754
# 4  foo    two  2.542560  0.872077
# 5  bar    two -0.737196 -1.041347
# 6  foo    one  0.351952 -1.879765
# 7  foo  three  1.047224  0.453515

# %% [markdown]
# Now let's group by column `A`, and `sum()` along the other columns:

# %%
foo_bar.groupby('A').sum()
# Out:
#                      B         C         D
# A
# bar        onethreetwo  1.184592 -2.127821
# foo  onetwotwoonethree  3.806310 -1.137558

# %% [markdown]
# Note that column `B` doesn't make a ton of sense, because the summation operator concatenated all the strings. However, if we wanted to retain that information, we could perform the same operation using a hierarchical index:

# %%
grouped = foo_bar.groupby(['A','B']).sum()
grouped
# Out:
#                   C         D
# A   B
# bar one    1.382790 -0.927720
#     three  0.538998 -0.158754
#     two   -0.737196 -1.041347
# foo one    0.511243 -2.701750
#     three  1.047224  0.453515
#     two    2.247843  1.110677

# %% [markdown]
# The `stack()` function can be used to "compress” a level in the `DataFrame`’s columns:

# %%
stacked = grouped.stack()
stacked
# Out:
# A    B
# bar  one    C    1.382790
#             D   -0.927720
#      three  C    0.538998
#             D   -0.158754
#      two    C   -0.737196
#             D   -1.041347
# foo  one    C    0.511243
#             D   -2.701750
#      three  C    1.047224
#             D    0.453515
#      two    C    2.247843
#             D    1.110677
# dtype: float64

# %% [markdown]
# To uncompress the last column of a stacked `DataFrame`, you can call `.unstack()`:

# %%
stacked.unstack()
# Out:
#                   C         D
# A   B
# bar one    1.382790 -0.927720
#     three  0.538998 -0.158754
#     two   -0.737196 -1.041347
# foo one    0.511243 -2.701750
#     three  1.047224  0.453515
#     two    2.247843  1.110677

# %% [markdown]
# ## Time Series
# `pandas` has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (for example, converting secondly data into minutely data). Firset, let's create an array of 150 `dateTime` objects at a frequency of 1 second:

# %%
rng = pandas.date_range('1/1/2021', 
                        periods = 350, 
                        freq = 'S')
rng
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 00:00:01',
#                '2021-01-01 00:00:02', '2021-01-01 00:00:03',
#                '2021-01-01 00:00:04', '2021-01-01 00:00:05',
#                '2021-01-01 00:00:06', '2021-01-01 00:00:07',
#                '2021-01-01 00:00:08', '2021-01-01 00:00:09',
#                ...
#                '2021-01-01 00:05:40', '2021-01-01 00:05:41',
#                '2021-01-01 00:05:42', '2021-01-01 00:05:43',
#                '2021-01-01 00:05:44', '2021-01-01 00:05:45',
#                '2021-01-01 00:05:46', '2021-01-01 00:05:47',
#                '2021-01-01 00:05:48', '2021-01-01 00:05:49'],
#               dtype='datetime64[ns]', length=350, freq='S')

# %% [markdown]
# Now we'll use that to create a time series, assigning a random integer to each element of the range:

# %%
time_series = pandas.Series(numpy.random.randint(0, 500, len(rng)), 
                            index = rng)
time_series.head()
# Out:
# 2021-01-01 00:00:00    474
# 2021-01-01 00:00:01    304
# 2021-01-01 00:00:02    282
# 2021-01-01 00:00:03    181
# 2021-01-01 00:00:04    374
# Freq: S, dtype: int64

# %% [markdown]
# Next, we'll resample the data by binning the one-second raw values into minutes (and summing the associated values):

# %%
time_series.resample('1Min').sum()
# Out:
# 2021-01-01 00:00:00    13753
# 2021-01-01 00:01:00    14051
# 2021-01-01 00:02:00    16498
# 2021-01-01 00:03:00    14979
# 2021-01-01 00:04:00    13111
# 2021-01-01 00:05:00    12108
# Freq: T, dtype: int64

# %% [markdown]
# We also have support for time zone conversion. For example, if we assume the original `time_series` was in UTC:

# %%
ts_utc = time_series.tz_localize('UTC')
ts_utc.head()
# Out:
# 2021-01-01 00:00:00+00:00    474
# 2021-01-01 00:00:01+00:00    304
# 2021-01-01 00:00:02+00:00    282
# 2021-01-01 00:00:03+00:00    181
# 2021-01-01 00:00:04+00:00    374
# Freq: S, dtype: int64

# %% [markdown]
# We can easily convert it to Eastern time:

# %%
ts_utc.tz_convert('US/Eastern').head()
# Out:
# 2020-12-31 19:00:00-05:00    474
# 2020-12-31 19:00:01-05:00    304
# 2020-12-31 19:00:02-05:00    282
# 2020-12-31 19:00:03-05:00    181
# 2020-12-31 19:00:04-05:00    374
# Freq: S, dtype: int64

# %% [markdown]
# ## Reading/Writing to files
# Writing to a file works just like we'd expect:

# %%
ts_utc.to_csv("foo.csv")

# %% [markdown]
# As does reading:

# %%
new_frame = pandas.read_csv("foo.csv")
new_frame.head()
# Out:
#                   Unnamed: 0    0
# 0  2021-01-01 00:00:00+00:00  474
# 1  2021-01-01 00:00:01+00:00  304
# 2  2021-01-01 00:00:02+00:00  282
# 3  2021-01-01 00:00:03+00:00  181
# 4  2021-01-01 00:00:04+00:00  374

# %% [markdown]
# We can also read/write to `.xlsx` format, if for some reason we want to work in Excel:

# %%
# excel conversion won't support timezones so we have to remove them first
ts_none = ts_utc.tz_localize(None)

ts_none.to_excel("foo.xlsx", sheet_name = "Sample 1")

# %% [markdown]
# But what if the data is a little... messy? Something like this:

# %%
broken_df = pandas.read_csv('bikes.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 broken_df = pandas.read_csv('bikes.csv')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:668, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 15: invalid continuation byte

# %% [markdown]
# No problem! The `read_csv()` function has lots of tools to help wrangle this mess. Here we'll
#
#     - change the column separator to a ;
#     - Set the encoding to `latin1` (the default is `utf8`)
#     - Parse the dates in the `Date` column
#     - Tell it that our dates have the day first instead of the month first

# %%
fixed_df = pandas.read_csv('bikes.csv', 
                           sep = ';', 
                           encoding = 'latin1', 
                           parse_dates = ['Date'], 
                           dayfirst = True)
fixed_df.head()
# Out:
#         Date  Berri 1  Brébeuf (données non disponibles)  \
# 0 2012-01-01       35                                NaN
# 1 2012-01-02       83                                NaN
# 2 2012-01-03      135                                NaN
# 3 2012-01-04      144                                NaN
# 4 2012-01-05      197                                NaN
#
#    Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
# 3                      1            116            318      111             8
# 4                      2            124            330       97            13
#
#    Rachel1  St-Urbain (données non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# 2       58                                  NaN
# 3       61                                  NaN
# 4       95                                  NaN

# %% [markdown]
# ## Scraping Data
# Many of you will probably be interested in scraping data from the web for your projects. For example, what if we were interested in working with some data on municipalities in the state of Massachusetts? Well, we can get that from https://en.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts
#
# First, we'll import two useful libraries: `requests` (to query a URL) and `BeautifulSoup` (to parse the web page):

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Now let's request the page:

# %%
result = requests.get("https://en.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts")
result
# Out:
# <Response [200]>

# %% [markdown]
# The response code `[200]` indicates that the request was successful. Now let's use `BeautifulSoup` to parse the web page into something semi-readable:

# %%
page = result.content
soup = BeautifulSoup(page)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of municipalities in Massachusetts - Wikipedia
#   </title>
#   <script>
#    (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":[
# "",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"32bdff05-7ebc-4c9c-affa-a54ebb3e16c6","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_municipalities_in_Massachusetts","wgTitle":"List of municipalities in Massachusetts","wgCurRevisionId":1235412707,"wgRevisionId":1235412707,"wgArticleId":8673763,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with dead external links","Articles with dead external links from April 2020","Articles with short description","Short description is different from Wikidata","Use mdy dates from May 2024","Wikipedia articles in need of updating from June 2023","All Wikipedia articles in need of updating","Wikipedia articles needing clarification from April 2023","Commons category link is on Wikidata",
# "Cities in Massachusetts","Towns in Massachusetts","Lists of places in Massachusetts","Lists of cities in the United States by state","Lists of towns in the United States"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_municipalities_in_Massachusetts","wgRelevantArticleId":8673763,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":100000,"wgULSCurrentAutonym":"English","wgRelatedArticlesCompat":[],
# "wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q1761265","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready",
# "ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.media","ext.scribunto.logs","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession","wikibase.sidebar.tracking"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cext.wikimediamessages.styles%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.icons%2Cstyles%7Cskins.vector.search.codex.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
#   <meta content="MediaWiki 1.43.0-wmf.20" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="max-image-preview:standard" name="robots"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/2/28/Ma_towns.png" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="735" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/2/28/Ma_towns.png" property="og:image"/>
#   <meta content="800" property="og:image:width"/>
#   <meta content="490" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/28/Ma_towns.png/640px-Ma_towns.png" property="og:image"/>
#   <meta content="640" property="og:image:width"/>
#   <meta content="392" property="og:image:height"/>
#   <meta content="width=1120" name="viewport"/>
#   <meta content="List of municipalities in Massachusetts - Wikipedia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="icon"/>
#   <link href="/w/rest.php/v1/search" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="https://en.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts" rel="canonical"/>
#   <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.en" rel="license"/>
#   <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="skin--responsive skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_municipalities_in_Massachusetts rootpage-List_of_municipalities_in_Massachusetts skin-vector-2022 action-view">
#   <a class="mw-jump-link" href="#bodyContent">
#    Jump to content
#   </a>
#   <div class="vector-header-container">
#    <header class="vector-header mw-header">
#     <div class="vector-header-start">
#      <nav aria-label="Site" class="vector-main-menu-landmark">
#       <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
#        <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
#        <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label">
#         <span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu">
#         </span>
#         <span class="vector-dropdown-label-text">
#          Main menu
#         </span>
#        </label>
#        <div class="vector-dropdown-content">
#         <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
#          <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
#           <div class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned" data-feature-name="main-menu-pinned" data-pinnable-element-id="vector-main-menu" data-pinned-container-id="vector-main-menu-pinned-container" data-unpinned-container-id="vector-main-menu-unpinned-container">
#            <div class="vector-pinnable-header-label">
#             Main menu
#            </div>
#            <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">
#             move to sidebar
#            </button>
#            <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">
#             hide
#            </button>
#           </div>
#           <div class="vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
#            <div class="vector-menu-heading">
#             Navigation
#            </div>
#            <div class="vector-menu-content">
#             <ul class="vector-menu-content-list">
#              <li class="mw-list-item" id="n-mainpage-description">
#               <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#                <span>
#                 Main page
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-contents">
#               <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">
#                <span>
#                 Contents
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-currentevents">
#               <a href="/wiki/Portal:Current_events" title="Articles related to current events">
#                <span>
#                 Current events
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-randompage">
#               <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">
#                <span>
#                 Random article
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-aboutsite">
#               <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">
#                <span>
#                 About Wikipedia
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-contactpage">
#               <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#                <span>
#                 Contact us
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-sitesupport">
#               <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">
#                <span>
#                 Donate
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="vector-menu mw-portlet mw-portlet-interaction" id="p-interaction">
#            <div class="vector-menu-heading">
#             Contribute
#            </div>
#            <div class="vector-menu-content">
#             <ul class="vector-menu-content-list">
#              <li class="mw-list-item" id="n-help">
#               <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#                <span>
#                 Help
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-introduction">
#               <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">
#                <span>
#                 Learn to edit
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-portal">
#               <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">
#                <span>
#                 Community portal
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-recentchanges">
#               <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">
#                <span>
#                 Recent changes
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-upload">
#               <a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia">
#                <span>
#                 Upload file
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#      <a class="mw-logo" href="/wiki/Main_Page">
#       <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
#       <span class="mw-logo-container skin-invert">
#        <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
#        <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
#       </span>
#      </a>
#     </div>
#     <div class="vector-header-end">
#      <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
#       <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Special:Search" title="Search Wikipedia [f]">
#        <span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search">
#        </span>
#        <span>
#         Search
#        </span>
#       </a>
#       <div class="vector-typeahead-search-container">
#        <div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
#         <form action="/w/index.php" class="cdx-search-input cdx-search-input--has-end-button" id="searchform">
#          <div class="cdx-search-input__input-wrapper" data-search-loc="header-moved" id="simpleSearch">
#           <div class="cdx-text-input cdx-text-input--has-start-icon">
#            <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="cdx-text-input__input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#            <span class="cdx-text-input__icon cdx-text-input__start-icon">
#            </span>
#           </div>
#           <input name="title" type="hidden" value="Special:Search"/>
#          </div>
#          <button class="cdx-button cdx-search-input__end-button">
#           Search
#          </button>
#         </form>
#        </div>
#       </div>
#      </div>
#      <nav aria-label="Personal tools" class="vector-user-links vector-user-links-wide">
#       <div class="vector-user-links-main">
#        <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-preferences">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#          </ul>
#         </div>
#        </div>
#        <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-userpage">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#          </ul>
#         </div>
#        </div>
#        <nav aria-label="Appearance" class="vector-appearance-landmark">
#         <div class="vector-dropdown" id="vector-appearance-dropdown">
#          <input aria-haspopup="true" aria-label="Appearance" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-appearance-dropdown" id="vector-appearance-dropdown-checkbox" role="button" type="checkbox"/>
#          <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-appearance-dropdown-checkbox" id="vector-appearance-dropdown-label">
#           <span class="vector-icon mw-ui-icon-appearance mw-ui-icon-wikimedia-appearance">
#           </span>
#           <span class="vector-dropdown-label-text">
#            Appearance
#           </span>
#          </label>
#          <div class="vector-dropdown-content">
#           <div class="vector-unpinned-container" id="vector-appearance-unpinned-container">
#           </div>
#          </div>
#         </div>
#        </nav>
#        <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-notifications">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#          </ul>
#         </div>
#        </div>
#        <div class="vector-menu mw-portlet" id="p-vector-user-menu-overflow">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-createaccount-2">
#            <a class="" data-mw="interface" href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+municipalities+in+Massachusetts" title="You are encouraged to create an account and log in; however, it is not mandatory">
#             <span>
#              Create account
#             </span>
#            </a>
#           </li>
#           <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-login-2">
#            <a accesskey="o" class="" data-mw="interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+municipalities+in+Massachusetts" title="You're encouraged to log in; however, it's not mandatory. [o]">
#             <span>
#              Log in
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out" id="vector-user-links-dropdown" title="Log in and more options">
#        <input aria-haspopup="true" aria-label="Personal tools" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-user-links-dropdown" id="vector-user-links-dropdown-checkbox" role="button" type="checkbox"/>
#        <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-user-links-dropdown-checkbox" id="vector-user-links-dropdown-label">
#         <span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis">
#         </span>
#         <span class="vector-dropdown-label-text">
#          Personal tools
#         </span>
#        </label>
#        <div class="vector-dropdown-content">
#         <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="User menu">
#          <div class="vector-menu-content">
#           <ul class="vector-menu-content-list">
#            <li class="user-links-collapsible-item mw-list-item" id="pt-createaccount">
#             <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+municipalities+in+Massachusetts" title="You are encouraged to create an account and log in; however, it is not mandatory">
#              <span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd">
#              </span>
#              <span>
#               Create account
#              </span>
#             </a>
#            </li>
#            <li class="user-links-collapsible-item mw-list-item" id="pt-login">
#             <a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+municipalities+in+Massachusetts" title="You're encouraged to log in; however, it's not mandatory. [o]">
#              <span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn">
#              </span>
#              <span>
#               Log in
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor" id="p-user-menu-anon-editor">
#          <div class="vector-menu-heading">
#           Pages for logged out editors
#           <a aria-label="Learn more about editing" href="/wiki/Help:Introduction">
#            <span>
#             learn more
#            </span>
#           </a>
#          </div>
#          <div class="vector-menu-content">
#           <ul class="vector-menu-content-list">
#            <li class="mw-list-item" id="pt-anoncontribs">
#             <a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]">
#              <span>
#               Contributions
#              </span>
#             </a>
#            </li>
#            <li class="mw-list-item" id="pt-anontalk">
#             <a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]">
#              <span>
#               Talk
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#    </header>
#   </div>
#   <div class="mw-page-container">
#    <div class="mw-page-container-inner">
#     <div class="vector-sitenotice-container">
#      <div class="notheme" id="siteNotice">
#       <!-- CentralNotice -->
#      </div>
#     </div>
#     <div class="vector-column-start">
#      <div class="vector-main-menu-container">
#       <div id="mw-navigation">
#        <nav aria-label="Site" class="vector-main-menu-landmark" id="mw-panel">
#         <div class="vector-pinned-container" id="vector-main-menu-pinned-container">
#         </div>
#        </nav>
#       </div>
#      </div>
#      <div class="vector-sticky-pinned-container">
#       <nav aria-label="Contents" class="mw-table-of-contents-container vector-toc-landmark" data-event-name="ui.sidebar-toc" id="mw-panel-toc">
#        <div class="vector-pinned-container" id="vector-toc-pinned-container">
#         <div class="vector-toc vector-pinnable-element" id="vector-toc">
#          <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-feature-name="toc-pinned" data-pinnable-element-id="vector-toc">
#           <h2 class="vector-pinnable-header-label">
#            Contents
#           </h2>
#           <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">
#            move to sidebar
#           </button>
#           <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">
#            hide
#           </button>
#          </div>
#          <ul class="vector-toc-contents" id="mw-panel-toc-list">
#           <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
#            <a class="vector-toc-link" href="#">
#             <div class="vector-toc-text">
#              (Top)
#             </div>
#            </a>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Largest_cities">
#            <a class="vector-toc-link" href="#Largest_cities">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               1
#              </span>
#              <span>
#               Largest cities
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-Largest_cities-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-List_of_municipalities">
#            <a class="vector-toc-link" href="#List_of_municipalities">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               2
#              </span>
#              <span>
#               List of municipalities
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-List_of_municipalities-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Geography_of_towns_at_formation">
#            <a class="vector-toc-link" href="#Geography_of_towns_at_formation">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               3
#              </span>
#              <span>
#               Geography of towns at formation
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-Geography_of_towns_at_formation-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Former_municipalities">
#            <a class="vector-toc-link" href="#Former_municipalities">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               4
#              </span>
#              <span>
#               Former municipalities
#              </span>
#             </div>
#            </a>
#            <button aria-controls="toc-Former_municipalities-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
#             <span class="vector-icon mw-ui-icon-wikimedia-expand">
#             </span>
#             <span>
#              Toggle Former municipalities subsection
#             </span>
#            </button>
#            <ul class="vector-toc-list" id="toc-Former_municipalities-sublist">
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Annexations">
#              <a class="vector-toc-link" href="#Annexations">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 4.1
#                </span>
#                <span>
#                 Annexations
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Annexations-sublist">
#              </ul>
#             </li>
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Disincorporations">
#              <a class="vector-toc-link" href="#Disincorporations">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 4.2
#                </span>
#                <span>
#                 Disincorporations
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Disincorporations-sublist">
#              </ul>
#             </li>
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Cessions">
#              <a class="vector-toc-link" href="#Cessions">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 4.3
#                </span>
#                <span>
#                 Cessions
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Cessions-sublist">
#               <li class="vector-toc-list-item vector-toc-level-3" id="toc-Ceded_to_New_Hampshire">
#                <a class="vector-toc-link" href="#Ceded_to_New_Hampshire">
#                 <div class="vector-toc-text">
#                  <span class="vector-toc-numb">
#                   4.3.1
#                  </span>
#                  <span>
#                   Ceded to New Hampshire
#                  </span>
#                 </div>
#                </a>
#                <ul class="vector-toc-list" id="toc-Ceded_to_New_Hampshire-sublist">
#                </ul>
#               </li>
#               <li class="vector-toc-list-item vector-toc-level-3" id="toc-Ceded_to_Rhode_Island">
#                <a class="vector-toc-link" href="#Ceded_to_Rhode_Island">
#                 <div class="vector-toc-text">
#                  <span class="vector-toc-numb">
#                   4.3.2
#                  </span>
#                  <span>
#                   Ceded to Rhode Island
#                  </span>
#                 </div>
#                </a>
#                <ul class="vector-toc-list" id="toc-Ceded_to_Rhode_Island-sublist">
#                </ul>
#               </li>
#               <li class="vector-toc-list-item vector-toc-level-3" id="toc-Ceded_to_Connecticut">
#                <a class="vector-toc-link" href="#Ceded_to_Connecticut">
#                 <div class="vector-toc-text">
#                  <span class="vector-toc-numb">
#                   4.3.3
#                  </span>
#                  <span>
#                   Ceded to Connecticut
#                  </span>
#                 </div>
#                </a>
#                <ul class="vector-toc-list" id="toc-Ceded_to_Connecticut-sublist">
#                </ul>
#               </li>
#               <li class="vector-toc-list-item vector-toc-level-3" id="toc-Ceded_to_Maine">
#                <a class="vector-toc-link" href="#Ceded_to_Maine">
#                 <div class="vector-toc-text">
#                  <span class="vector-toc-numb">
#                   4.3.4
#                  </span>
#                  <span>
#                   Ceded to Maine
#                  </span>
#                 </div>
#                </a>
#                <ul class="vector-toc-list" id="toc-Ceded_to_Maine-sublist">
#                </ul>
#               </li>
#              </ul>
#             </li>
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Archaic_names">
#            <a class="vector-toc-link" href="#Archaic_names">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               5
#              </span>
#              <span>
#               Archaic names
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-Archaic_names-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-See_also">
#            <a class="vector-toc-link" href="#See_also">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               6
#              </span>
#              <span>
#               See also
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-See_also-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Notes">
#            <a class="vector-toc-link" href="#Notes">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               7
#              </span>
#              <span>
#               Notes
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-Notes-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-References">
#            <a class="vector-toc-link" href="#References">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               8
#              </span>
#              <span>
#               References
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-References-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-External_links">
#            <a class="vector-toc-link" href="#External_links">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               9
#              </span>
#              <span>
#               External links
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-External_links-sublist">
#            </ul>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </nav>
#      </div>
#     </div>
#     <div class="mw-content-container">
#      <main class="mw-body" id="content">
#       <header class="mw-body-header vector-page-titlebar">
#        <nav aria-label="Contents" class="vector-toc-landmark">
#         <div class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left" id="vector-page-titlebar-toc">
#          <input aria-haspopup="true" aria-label="Toggle the table of contents" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox"/>
#          <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label">
#           <span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet">
#           </span>
#           <span class="vector-dropdown-label-text">
#            Toggle the table of contents
#           </span>
#          </label>
#          <div class="vector-dropdown-content">
#           <div class="vector-unpinned-container" id="vector-page-titlebar-toc-unpinned-container">
#           </div>
#          </div>
#         </div>
#        </nav>
#        <h1 class="firstHeading mw-first-heading" id="firstHeading">
#         <span class="mw-page-title-main">
#          List of municipalities in Massachusetts
#         </span>
#        </h1>
#        <div class="vector-dropdown mw-portlet mw-portlet-lang" id="p-lang-btn">
#         <input aria-haspopup="true" aria-label="Go to an article in another language. Available in 17 languages" class="vector-dropdown-checkbox mw-interlanguage-selector" data-event-name="ui.dropdown-p-lang-btn" id="p-lang-btn-checkbox" role="button" type="checkbox"/>
#         <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-17" for="p-lang-btn-checkbox" id="p-lang-btn-label">
#          <span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive">
#          </span>
#          <span class="vector-dropdown-label-text">
#           17 languages
#          </span>
#         </label>
#         <div class="vector-dropdown-content">
#          <div class="vector-menu-content">
#           <ul class="vector-menu-content-list">
#            <li class="interlanguage-link interwiki-ar mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="العربية" data-language-local-name="Arabic" data-title="قائمة بلديات ماساتشوستس" href="https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A8%D9%84%D8%AF%D9%8A%D8%A7%D8%AA_%D9%85%D8%A7%D8%B3%D8%A7%D8%AA%D8%B4%D9%88%D8%B3%D8%AA%D8%B3" hreflang="ar" lang="ar" title="قائمة بلديات ماساتشوستس – Arabic">
#              <span>
#               العربية
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-bar mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Boarisch" data-language-local-name="Bavarian" data-title="Städt in Massachusetts" href="https://bar.wikipedia.org/wiki/St%C3%A4dt_in_Massachusetts" hreflang="bar" lang="bar" title="Städt in Massachusetts – Bavarian">
#              <span>
#               Boarisch
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-de mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Deutsch" data-language-local-name="German" data-title="Liste der Städte in Massachusetts" href="https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_Massachusetts" hreflang="de" lang="de" title="Liste der Städte in Massachusetts – German">
#              <span>
#               Deutsch
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-es mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Español" data-language-local-name="Spanish" data-title="Anexo:Localidades de Massachusetts" href="https://es.wikipedia.org/wiki/Anexo:Localidades_de_Massachusetts" hreflang="es" lang="es" title="Anexo:Localidades de Massachusetts – Spanish">
#              <span>
#               Español
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-fa mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="فارسی" data-language-local-name="Persian" data-title="فهرست شهرهای ماساچوست" href="https://fa.wikipedia.org/wiki/%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D8%B4%D9%87%D8%B1%D9%87%D8%A7%DB%8C_%D9%85%D8%A7%D8%B3%D8%A7%DA%86%D9%88%D8%B3%D8%AA" hreflang="fa" lang="fa" title="فهرست شهرهای ماساچوست – Persian">
#              <span>
#               فارسی
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-fr mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Français" data-language-local-name="French" data-title="Liste des municipalités du Massachusetts" href="https://fr.wikipedia.org/wiki/Liste_des_municipalit%C3%A9s_du_Massachusetts" hreflang="fr" lang="fr" title="Liste des municipalités du Massachusetts – French">
#              <span>
#               Français
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-it mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Italiano" data-language-local-name="Italian" data-title="Città del Massachusetts" href="https://it.wikipedia.org/wiki/Citt%C3%A0_del_Massachusetts" hreflang="it" lang="it" title="Città del Massachusetts – Italian">
#              <span>
#               Italiano
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-sw mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Kiswahili" data-language-local-name="Swahili" data-title="Orodha ya miji ya Massachusetts" href="https://sw.wikipedia.org/wiki/Orodha_ya_miji_ya_Massachusetts" hreflang="sw" lang="sw" title="Orodha ya miji ya Massachusetts – Swahili">
#              <span>
#               Kiswahili
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-no mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Norsk bokmål" data-language-local-name="Norwegian Bokmål" data-title="Liste over byer i Massachusetts" href="https://no.wikipedia.org/wiki/Liste_over_byer_i_Massachusetts" hreflang="nb" lang="nb" title="Liste over byer i Massachusetts – Norwegian Bokmål">
#              <span>
#               Norsk bokmål
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-pt mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Português" data-language-local-name="Portuguese" data-title="Lista de cidades de Massachusetts" href="https://pt.wikipedia.org/wiki/Lista_de_cidades_de_Massachusetts" hreflang="pt" lang="pt" title="Lista de cidades de Massachusetts – Portuguese">
#              <span>
#               Português
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-ro mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Română" data-language-local-name="Romanian" data-title="Listă de orașe din statul Massachusetts" href="https://ro.wikipedia.org/wiki/List%C4%83_de_ora%C8%99e_din_statul_Massachusetts" hreflang="ro" lang="ro" title="Listă de orașe din statul Massachusetts – Romanian">
#              <span>
#               Română
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-ru mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Русский" data-language-local-name="Russian" data-title="Список городов Массачусетса по численности населения" href="https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%B3%D0%BE%D1%80%D0%BE%D0%B4%D0%BE%D0%B2_%D0%9C%D0%B0%D1%81%D1%81%D0%B0%D1%87%D1%83%D1%81%D0%B5%D1%82%D1%81%D0%B0_%D0%BF%D0%BE_%D1%87%D0%B8%D1%81%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE%D1%81%D1%82%D0%B8_%D0%BD%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F" hreflang="ru" lang="ru" title="Список городов Массачусетса по численности населения – Russian">
#              <span>
#               Русский
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-simple mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Simple English" data-language-local-name="Simple English" data-title="List of cities and towns in Massachusetts" href="https://simple.wikipedia.org/wiki/List_of_cities_and_towns_in_Massachusetts" hreflang="en-simple" lang="en-simple" title="List of cities and towns in Massachusetts – Simple English">
#              <span>
#               Simple English
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-tl mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Tagalog" data-language-local-name="Tagalog" data-title="Talaan ng mga lungsod sa Massachusetts" href="https://tl.wikipedia.org/wiki/Talaan_ng_mga_lungsod_sa_Massachusetts" hreflang="tl" lang="tl" title="Talaan ng mga lungsod sa Massachusetts – Tagalog">
#              <span>
#               Tagalog
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-tr mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="Türkçe" data-language-local-name="Turkish" data-title="Massachusetts'deki şehirler listesi" href="https://tr.wikipedia.org/wiki/Massachusetts%27deki_%C5%9Fehirler_listesi" hreflang="tr" lang="tr" title="Massachusetts'deki şehirler listesi – Turkish">
#              <span>
#               Türkçe
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-ur mw-list-item">
#             <a class="interlanguage-link-target" data-language-autonym="اردو" data-language-local-name="Urdu" data-title="میساچوسٹس میں بلدیات کی فہرست" href="https://ur.wikipedia.org/wiki/%D9%85%DB%8C%D8%B3%D8%A7%DA%86%D9%88%D8%B3%D9%B9%D8%B3_%D9%85%DB%8C%DA%BA_%D8%A8%D9%84%D8%AF%DB%8C%D8%A7%D8%AA_%DA%A9%DB%8C_%D9%81%DB%81%D8%B1%D8%B3%D8%AA" hreflang="ur" lang="ur" title="میساچوسٹس میں بلدیات کی فہرست – Urdu">
#              <span>
#               اردو
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-zh badge-Q17506997 badge-featuredlist mw-list-item" title="featured list badge">
#             <a class="interlanguage-link-target" data-language-autonym="中文" data-language-local-name="Chinese" data-title="马萨诸塞州市镇列表" href="https://zh.wikipedia.org/wiki/%E9%A9%AC%E8%90%A8%E8%AF%B8%E5%A1%9E%E5%B7%9E%E5%B8%82%E9%95%87%E5%88%97%E8%A1%A8" hreflang="zh" lang="zh" title="马萨诸塞州市镇列表 – Chinese">
#              <span>
#               中文
#              </span>
#             </a>
#            </li>
#           </ul>
#           <div class="after-portlet after-portlet-lang">
#            <span class="wb-langlinks-edit wb-langlinks-link">
#             <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1761265#sitelinks-wikipedia" title="Edit interlanguage links">
#              Edit links
#             </a>
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </header>
#       <div class="vector-page-toolbar">
#        <div class="vector-page-toolbar-container">
#         <div id="left-navigation">
#          <nav aria-label="Namespaces">
#           <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages" id="p-associated-pages">
#            <div class="vector-menu-content">
#             <ul class="vector-menu-content-list">
#              <li class="selected vector-tab-noicon mw-list-item" id="ca-nstab-main">
#               <a accesskey="c" href="/wiki/List_of_municipalities_in_Massachusetts" title="View the content page [c]">
#                <span>
#                 Article
#                </span>
#               </a>
#              </li>
#              <li class="vector-tab-noicon mw-list-item" id="ca-talk">
#               <a accesskey="t" href="/wiki/Talk:List_of_municipalities_in_Massachusetts" rel="discussion" title="Discuss improvements to the content page [t]">
#                <span>
#                 Talk
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="vector-dropdown emptyPortlet" id="vector-variants-dropdown">
#            <input aria-haspopup="true" aria-label="Change language variant" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-variants-dropdown" id="vector-variants-dropdown-checkbox" role="button" type="checkbox"/>
#            <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="vector-variants-dropdown-checkbox" id="vector-variants-dropdown-label">
#             <span class="vector-dropdown-label-text">
#              English
#             </span>
#            </label>
#            <div class="vector-dropdown-content">
# ...
#                   Wyoming
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </td>
#             </tr>
#             <tr>
#              <th class="navbox-group" scope="row" style="width:1%;text-align:right; vertical-align:top;">
#               <a href="/wiki/Lists_of_populated_places_in_the_United_States" title="Lists of populated places in the United States">
#                D.C. &amp; territories
#               </a>
#              </th>
#              <td class="navbox-list-with-group navbox-list navbox-even" style="width:100%;padding:0">
#               <div style="padding:0 0.25em">
#                <ul>
#                 <li>
#                  <a href="/wiki/Administrative_divisions_of_American_Samoa" title="Administrative divisions of American Samoa">
#                   American Samoa
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/Neighborhoods_in_Washington,_D.C." title="Neighborhoods in Washington, D.C.">
#                   District of Columbia
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/Villages_of_Guam" title="Villages of Guam">
#                   Guam
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/List_of_populated_places_in_the_Northern_Mariana_Islands" title="List of populated places in the Northern Mariana Islands">
#                   Northern Mariana Islands
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/Municipalities_of_Puerto_Rico" title="Municipalities of Puerto Rico">
#                   Puerto Rico
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/List_of_settlements_in_the_United_States_Virgin_Islands" title="List of settlements in the United States Virgin Islands">
#                   U.S. Virgin Islands
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </td>
#             </tr>
#             <tr>
#              <th class="navbox-group" scope="row" style="width:1%;text-align:right; vertical-align:top;">
#               <a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">
#                By population
#               </a>
#              </th>
#              <td class="navbox-list-with-group navbox-list navbox-odd" style="width:100%;padding:0">
#               <div style="padding:0 0.25em">
#                <ul>
#                 <li>
#                  <a class="mw-redirect" href="/wiki/List_of_largest_California_cities_by_population" title="List of largest California cities by population">
#                   California
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/List_of_municipalities_in_Wisconsin_by_population" title="List of municipalities in Wisconsin by population">
#                   Wisconsin
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <!--
# NewPP limit report
# Parsed by mw‐web.eqiad.main‐66686d9d75‐zd8gx
# Cached time: 20240903213450
# Cache expiry: 2592000
# Reduced expiry: false
# Complications: [vary‐revision‐sha1, show‐toc]
# CPU time usage: 1.598 seconds
# Real time usage: 1.884 seconds
# Preprocessor visited node count: 4563/1000000
# Post‐expand include size: 97954/2097152 bytes
# Template argument size: 17643/2097152 bytes
# Highest expansion depth: 17/100
# Expensive parser function count: 7/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 65336/5000000 bytes
# Lua time usage: 0.711/10.000 seconds
# Lua memory usage: 8495574/52428800 bytes
# Number of Wikibase entities loaded: 1/400
# -->
#          <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00% 1261.260      1 -total
#  19.87%  250.640      2 Template:Reflist
#  14.31%  180.545      6 Template:Cite_web
#  12.33%  155.571      1 Template:Infobox_subdivision_type
#  11.98%  151.122      1 Template:Infobox
#   9.80%  123.612      9 Template:Sfn
#   9.67%  121.904      1 Template:Largest_cities
#   9.59%  120.909     20 Template:Main_other
#   9.49%  119.675      1 Template:Commons_category
#   9.23%  116.388      1 Template:Sister_project
# -->
#          <!-- Saved in parser cache with key enwiki:pcache:idhash:8673763-0!canonical and timestamp 20240903213450 and revision id 1235412707. Rendering was triggered because: page-view
#  -->
#         </div>
#         <!--esi <esi:include src="/esitest-fa8a495983347898/content" /> -->
#         <noscript>
#          <img alt="" height="1" src="https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" width="1"/>
#         </noscript>
#         <div class="printfooter" data-nosnippet="">
#          Retrieved from "
#          <a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;oldid=1235412707">
#           https://en.wikipedia.org/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;oldid=1235412707
#          </a>
#          "
#         </div>
#        </div>
#        <div class="catlinks" data-mw="interface" id="catlinks">
#         <div class="mw-normal-catlinks" id="mw-normal-catlinks">
#          <a href="/wiki/Help:Category" title="Help:Category">
#           Categories
#          </a>
#          :
#          <ul>
#           <li>
#            <a href="/wiki/Category:Cities_in_Massachusetts" title="Category:Cities in Massachusetts">
#             Cities in Massachusetts
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Towns_in_Massachusetts" title="Category:Towns in Massachusetts">
#             Towns in Massachusetts
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Lists_of_places_in_Massachusetts" title="Category:Lists of places in Massachusetts">
#             Lists of places in Massachusetts
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Lists_of_cities_in_the_United_States_by_state" title="Category:Lists of cities in the United States by state">
#             Lists of cities in the United States by state
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Lists_of_towns_in_the_United_States" title="Category:Lists of towns in the United States">
#             Lists of towns in the United States
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">
#          Hidden categories:
#          <ul>
#           <li>
#            <a href="/wiki/Category:All_articles_with_dead_external_links" title="Category:All articles with dead external links">
#             All articles with dead external links
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_dead_external_links_from_April_2020" title="Category:Articles with dead external links from April 2020">
#             Articles with dead external links from April 2020
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">
#             Articles with short description
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">
#             Short description is different from Wikidata
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Use_mdy_dates_from_May_2024" title="Category:Use mdy dates from May 2024">
#             Use mdy dates from May 2024
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Wikipedia_articles_in_need_of_updating_from_June_2023" title="Category:Wikipedia articles in need of updating from June 2023">
#             Wikipedia articles in need of updating from June 2023
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:All_Wikipedia_articles_in_need_of_updating" title="Category:All Wikipedia articles in need of updating">
#             All Wikipedia articles in need of updating
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Wikipedia_articles_needing_clarification_from_April_2023" title="Category:Wikipedia articles needing clarification from April 2023">
#             Wikipedia articles needing clarification from April 2023
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Commons_category_link_is_on_Wikidata" title="Category:Commons category link is on Wikidata">
#             Commons category link is on Wikidata
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </main>
#     </div>
#     <div class="mw-footer-container">
#      <footer class="mw-footer" id="footer">
#       <ul id="footer-info">
#        <li id="footer-info-lastmod">
#         This page was last edited on 19 July 2024, at 04:57
#         <span class="anonymous-show">
#          (UTC)
#         </span>
#         .
#        </li>
#        <li id="footer-info-copyright">
#         Text is available under the
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license">
#          Creative Commons Attribution-ShareAlike License 4.0
#         </a>
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license" style="display:none;">
#         </a>
#         ;
# additional terms may apply. By using this site, you agree to the
#         <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use">
#          Terms of Use
#         </a>
#         and
#         <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">
#          Privacy Policy
#         </a>
#         . Wikipedia® is a registered trademark of the
#         <a href="//wikimediafoundation.org/">
#          Wikimedia Foundation, Inc.
#         </a>
#         , a non-profit organization.
#        </li>
#       </ul>
#       <ul id="footer-places">
#        <li id="footer-places-privacy">
#         <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">
#          Privacy policy
#         </a>
#        </li>
#        <li id="footer-places-about">
#         <a href="/wiki/Wikipedia:About">
#          About Wikipedia
#         </a>
#        </li>
#        <li id="footer-places-disclaimers">
#         <a href="/wiki/Wikipedia:General_disclaimer">
#          Disclaimers
#         </a>
#        </li>
#        <li id="footer-places-contact">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#          Contact Wikipedia
#         </a>
#        </li>
#        <li id="footer-places-wm-codeofconduct">
#         <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">
#          Code of Conduct
#         </a>
#        </li>
#        <li id="footer-places-developers">
#         <a href="https://developer.wikimedia.org">
#          Developers
#         </a>
#        </li>
#        <li id="footer-places-statslink">
#         <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#          Statistics
#         </a>
#        </li>
#        <li id="footer-places-cookiestatement">
#         <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">
#          Cookie statement
#         </a>
#        </li>
#        <li id="footer-places-mobileview">
#         <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;mobileaction=toggle_view_mobile">
#          Mobile view
#         </a>
#        </li>
#       </ul>
#       <ul class="noprint" id="footer-icons">
#        <li id="footer-copyrightico">
#         <a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://wikimediafoundation.org/" style="padding-left: 8px; padding-right: 8px;" target="https://wikimediafoundation.org/">
#          <img alt="Wikimedia Foundation" height="29" src="/static/images/footer/wikimedia-button.svg" width="84"/>
#         </a>
#        </li>
#        <li id="footer-poweredbyico">
#         <a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://www.mediawiki.org/">
#          <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/w/resources/assets/poweredby_mediawiki.svg" width="88"/>
#         </a>
#        </li>
#       </ul>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <div class="vector-settings" id="p-dock-bottom">
#    <ul>
#     <li>
#     </li>
#    </ul>
#   </div>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.eqiad.main-66686d9d75-2q6bz","wgBackendResponseTime":199,"wgPageParseReport":{"limitreport":{"cputime":"1.598","walltime":"1.884","ppvisitednodes":{"value":4563,"limit":1000000},"postexpandincludesize":{"value":97954,"limit":2097152},"templateargumentsize":{"value":17643,"limit":2097152},"expansiondepth":{"value":17,"limit":100},"expensivefunctioncount":{"value":7,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":65336,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 1261.260      1 -total"," 19.87%  250.640      2 Template:Reflist"," 14.31%  180.545      6 Template:Cite_web"," 12.33%  155.571      1 Template:Infobox_subdivision_type"," 11.98%  151.122      1 Template:Infobox","  9.80%  123.612      9 Template:Sfn","  9.67%  121.904      1 Template:Largest_cities","  9.59%  120.909     20 Template:Main_other","  9.49%  119.675      1 Template:Commons_category","  9.23%  116.388      1 Template:Sister_project"]},"scribunto":{"limitreport-timeusage":{"value":"0.711","limit":"10.000"},"limitreport-memusage":{"value":8495574,"limit":52428800},"limitreport-logs":"anchor_id_list = table#1 {\n    [\"CITEREFHanson1976\"] = 1,\n    [\"CITEREFKnight,_D.D.S.Davis,_Esq.Humphrey\"] = 1,\n    [\"CITEREFLockridge1985\"] = 1,\n}\ntemplate_list = table#1 {\n    [\"!\"] = 40,\n    [\"Cbignore\"] = 1,\n    [\"Cite book\"] = 2,\n    [\"Cite web\"] = 6,\n    [\"Clarify\"] = 1,\n    [\"Commons category\"] = 1,\n    [\"Convert\"] = 2,\n    [\"DEFAULTSORT:Municipalities In Massachusetts\"] = 1,\n    [\"Dead link\"] = 1,\n    [\"Div col\"] = 1,\n    [\"Div col end\"] = 1,\n    [\"Infobox subdivision type\"] = 1,\n    [\"Largest cities\"] = 1,\n    [\"Lists of settlements by U.S. state\"] = 1,\n    [\"Massachusetts\"] = 1,\n    [\"Notelist\"] = 1,\n    [\"Reflist\"] = 1,\n    [\"Sfn\"] = 9,\n    [\"Short description\"] = 1,\n    [\"Static row numbers\"] = 1,\n    [\"Update\"] = 1,\n    [\"Use mdy dates\"] = 1,\n}\narticle_whitelist = table#1 {\n}\ntable#1 {\n    [\"size\"] = \"small\",\n}\n"},"cachereport":{"origin":"mw-web.eqiad.main-66686d9d75-zd8gx","timestamp":"20240903213450","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"List of municipalities in Massachusetts","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_municipalities_in_Massachusetts","sameAs":"http:\/\/www.wikidata.org\/entity\/Q1761265","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q1761265","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2006-12-30T15:04:30Z","dateModified":"2024-07-19T04:57:39Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/2\/28\/Ma_towns.png","headline":"Wikimedia list article"}
#   </script>
#  </body>
# </html>

# %% [markdown]
# Notice that there's a lot of code in there that isn't related to the data we're trying to get. If we inspect the page source of the table we're interested in, we see that it's a `<table>` elemnt with `class = wikitable sortable static-row-numbers`. Let's ask `BeautifulSoup` to give us just that piece of the page:

# %%
table = soup.find("table", { "class" : "wikitable sortable static-row-numbers" })
print(table.prettify())
# Out:
# <table class="wikitable sortable static-row-numbers" style="text-align:center">
#  <tbody>
#   <tr class="static-row-header" style="text-align:center;vertical-align:bottom;">
#    <th>
#     Municipality
#    </th>
#    <th>
#     Type
#     <sup class="reference" id="cite_ref-MMA_1-0">
#      <a href="#cite_note-MMA-1">
#       <span class="cite-bracket">
#        [
#       </span>
#       1
#       <span class="cite-bracket">
#        ]
#       </span>
#      </a>
#     </sup>
#    </th>
#    <th data-sort-type="text">
#     County
#     <sup class="reference" id="cite_ref-census_2-0">
#      <a href="#cite_note-census-2">
#       <span class="cite-bracket">
#        [
#       </span>
#       2
#       <span class="cite-bracket">
#        ]
#       </span>
#      </a>
#     </sup>
#    </th>
#    <th>
#     Form of government
#     <sup class="reference" id="cite_ref-MMA_1-1">
#      <a href="#cite_note-MMA-1">
#       <span class="cite-bracket">
#        [
#       </span>
#       1
#       <span class="cite-bracket">
#        ]
#       </span>
#      </a>
#     </sup>
#    </th>
#    <th>
#     Population
#     <br/>
#     (2020)
#     <sup class="reference" id="cite_ref-census_2-1">
#      <a href="#cite_note-census-2">
#       <span class="cite-bracket">
#        [
#       </span>
#       2
#       <span class="cite-bracket">
#        ]
#       </span>
#      </a>
#     </sup>
#    </th>
#    <th>
#     Total area
#    </th>
#    <th>
#     Land area
#    </th>
#    <th>
#     Year
#     <br/>
#     established
#     <sup class="reference" id="cite_ref-CIS_3-0">
#      <a href="#cite_note-CIS-3">
#       <span class="cite-bracket">
#        [
#       </span>
#       3
#       <span class="cite-bracket">
#        ]
#       </span>
#      </a>
#     </sup>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     <b>
#      <a href="/wiki/Boston" title="Boston">
#       Boston
#      </a>
#     </b>
#    </td>
#    <td data-sort-value="City">
#     City (
#     <a href="/wiki/Capital_city" title="Capital city">
#      capital
#     </a>
#     )
#    </td>
#    <td data-sort-value="Suffolk">
#     <a href="/wiki/Suffolk_County,_Massachusetts" title="Suffolk County, Massachusetts">
#      Suffolk
#     </a>
#     (
#     <a href="/wiki/County_seat" title="County seat">
#      seat
#     </a>
#     )
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     675,647
#    </td>
#    <td>
#     89.6 sq mi (232.06 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     48.3 sq mi (125.10 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1630
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Worcester,_Massachusetts" title="Worcester, Massachusetts">
#      <b>
#       Worcester
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Worcester">
#     <a href="/wiki/Worcester_County,_Massachusetts" title="Worcester County, Massachusetts">
#      Worcester
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Manager-Council
#    </td>
#    <td>
#     206,518
#    </td>
#    <td>
#     38.5 sq mi (99.71 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     37.4 sq mi (96.87 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1684
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Springfield,_Massachusetts" title="Springfield, Massachusetts">
#      <b>
#       Springfield
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampden">
#     <a href="/wiki/Hampden_County,_Massachusetts" title="Hampden County, Massachusetts">
#      Hampden
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     155,929
#    </td>
#    <td>
#     33.1 sq mi (85.73 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     31.9 sq mi (82.62 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1636
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Cambridge,_Massachusetts" title="Cambridge, Massachusetts">
#      <b>
#       Cambridge
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     <a href="/wiki/Middlesex_County,_Massachusetts" title="Middlesex County, Massachusetts">
#      Middlesex
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Manager-Council
#    </td>
#    <td>
#     118,403
#    </td>
#    <td>
#     7.1 sq mi (18.39 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     6.4 sq mi (16.58 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1636
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Lowell,_Massachusetts" title="Lowell, Massachusetts">
#      <b>
#       Lowell
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex (seat)
#    </td>
#    <td>
#     Mayor-Manager-Council
#    </td>
#    <td>
#     115,554
#    </td>
#    <td>
#     14.5 sq mi (37.55 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     13.6 sq mi (35.22 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1826
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Brockton,_Massachusetts" title="Brockton, Massachusetts">
#      <b>
#       Brockton
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Plymouth">
#     <a href="/wiki/Plymouth_County,_Massachusetts" title="Plymouth County, Massachusetts">
#      Plymouth
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     105,643
#    </td>
#    <td>
#     21.5 sq mi (55.68 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     21.3 sq mi (55.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1821
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Quincy,_Massachusetts" title="Quincy, Massachusetts">
#      <b>
#       Quincy
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     101,636
#    </td>
#    <td>
#     26.9 sq mi (69.67 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     16.6 sq mi (42.99 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1792
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Lynn,_Massachusetts" title="Lynn, Massachusetts">
#      <b>
#       Lynn
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     101,253
#    </td>
#    <td>
#     13.5 sq mi (34.96 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     10.7 sq mi (27.71 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1629
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/New_Bedford,_Massachusetts" title="New Bedford, Massachusetts">
#      <b>
#       New Bedford
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Bristol">
#     Bristol
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     101,079
#    </td>
#    <td>
#     24.1 sq mi (62.42 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.0 sq mi (51.80 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1787
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Fall_River,_Massachusetts" title="Fall River, Massachusetts">
#      <b>
#       Fall River
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Bristol">
#     Bristol
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     94,000
#    </td>
#    <td>
#     40.2 sq mi (104.12 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     33.1 sq mi (85.73 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1803
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Lawrence,_Massachusetts" title="Lawrence, Massachusetts">
#      <b>
#       Lawrence
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     <a href="/wiki/Essex_County,_Massachusetts" title="Essex County, Massachusetts">
#      Essex
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     89,143
#    </td>
#    <td>
#     7.4 sq mi (19.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     6.9 sq mi (17.87 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1847
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Newton,_Massachusetts" title="Newton, Massachusetts">
#      <b>
#       Newton
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     88,923
#    </td>
#    <td>
#     18.2 sq mi (47.14 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     17.8 sq mi (46.10 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1688
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Somerville,_Massachusetts" title="Somerville, Massachusetts">
#      <b>
#       Somerville
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     81,045
#    </td>
#    <td>
#     4.2 sq mi (10.88 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     4.1 sq mi (10.62 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1842
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Framingham,_Massachusetts" title="Framingham, Massachusetts">
#      <b>
#       Framingham
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     72,362
#    </td>
#    <td>
#     26.5 sq mi (68.63 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     25.0 sq mi (64.75 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1700
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Haverhill,_Massachusetts" title="Haverhill, Massachusetts">
#      <b>
#       Haverhill
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     67,787
#    </td>
#    <td>
#     35.7 sq mi (92.46 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     33.0 sq mi (85.47 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1641
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Malden,_Massachusetts" title="Malden, Massachusetts">
#      <b>
#       Malden
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     66,263
#    </td>
#    <td>
#     5.1 sq mi (13.21 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     5.0 sq mi (12.95 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1649
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Waltham,_Massachusetts" title="Waltham, Massachusetts">
#      <b>
#       Waltham
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     65,218
#    </td>
#    <td>
#     13.8 sq mi (35.74 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     12.7 sq mi (32.89 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1738
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Brookline,_Massachusetts" title="Brookline, Massachusetts">
#      <b>
#       Brookline
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     63,191
#    </td>
#    <td>
#     6.8 sq mi (17.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     6.8 sq mi (17.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1705
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Revere,_Massachusetts" title="Revere, Massachusetts">
#      <b>
#       Revere
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Suffolk">
#     Suffolk
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     62,186
#    </td>
#    <td>
#     10.1 sq mi (26.16 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     5.7 sq mi (14.76 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1846
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Plymouth,_Massachusetts" title="Plymouth, Massachusetts">
#      <b>
#       Plymouth
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Plymouth">
#     Plymouth (seat)
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     61,217
#    </td>
#    <td>
#     134.0 sq mi (347.06 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     96.5 sq mi (249.93 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1620
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Medford,_Massachusetts" title="Medford, Massachusetts">
#      <b>
#       Medford
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     59,659
#    </td>
#    <td>
#     8.7 sq mi (22.53 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     8.1 sq mi (20.98 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1630
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Taunton,_Massachusetts" title="Taunton, Massachusetts">
#      <b>
#       Taunton
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Bristol">
#     <a href="/wiki/Bristol_County,_Massachusetts" title="Bristol County, Massachusetts">
#      Bristol
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     59,408
#    </td>
#    <td>
#     48.4 sq mi (125.36 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     46.7 sq mi (120.95 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1639
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Weymouth,_Massachusetts" title="Weymouth, Massachusetts">
#      <b>
#       Weymouth
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     57,437
#    </td>
#    <td>
#     21.6 sq mi (55.94 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     16.8 sq mi (43.51 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1635
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chicopee,_Massachusetts" title="Chicopee, Massachusetts">
#      <b>
#       Chicopee
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampden">
#     Hampden
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     55,560
#    </td>
#    <td>
#     23.9 sq mi (61.90 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     22.9 sq mi (59.31 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1848
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Peabody,_Massachusetts" title="Peabody, Massachusetts">
#      <b>
#       Peabody
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     54,481
#    </td>
#    <td>
#     16.8 sq mi (43.51 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     16.2 sq mi (41.96 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1868
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Methuen,_Massachusetts" title="Methuen, Massachusetts">
#      <b>
#       Methuen
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     53,039
#    </td>
#    <td>
#     23.0 sq mi (59.57 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     22.2 sq mi (57.50 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1725
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Everett,_Massachusetts" title="Everett, Massachusetts">
#      <b>
#       Everett
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     49,075
#    </td>
#    <td>
#     3.7 sq mi (9.58 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     3.4 sq mi (8.81 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1870
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Barnstable,_Massachusetts" title="Barnstable, Massachusetts">
#      <b>
#       Barnstable
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Barnstable">
#     <a href="/wiki/Barnstable_County,_Massachusetts" title="Barnstable County, Massachusetts">
#      Barnstable
#     </a>
#     (seat)
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td>
#     48,916
#    </td>
#    <td>
#     76.5 sq mi (198.13 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     59.3 sq mi (153.59 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1639
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Attleboro,_Massachusetts" title="Attleboro, Massachusetts">
#      <b>
#       Attleboro
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Bristol">
#     Bristol
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     46,461
#    </td>
#    <td>
#     27.8 sq mi (72.00 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     26.8 sq mi (69.41 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1694
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Arlington,_Massachusetts" title="Arlington, Massachusetts">
#      <b>
#       Arlington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     46,308
#    </td>
#    <td>
#     5.5 sq mi (14.24 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     5.0 sq mi (12.95 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1807
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Salem,_Massachusetts" title="Salem, Massachusetts">
#      <b>
#       Salem
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     Essex (seat)
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     44,480
#    </td>
#    <td>
#     18.3 sq mi (47.40 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     8.3 sq mi (21.50 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1626
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Pittsfield,_Massachusetts" title="Pittsfield, Massachusetts">
#      <b>
#       Pittsfield
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Berkshire">
#     <a href="/wiki/Berkshire_County,_Massachusetts" title="Berkshire County, Massachusetts">
#      Berkshire
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     43,927
#    </td>
#    <td>
#     42.5 sq mi (110.07 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     40.5 sq mi (104.89 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1761
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Leominster,_Massachusetts" title="Leominster, Massachusetts">
#      <b>
#       Leominster
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Worcester">
#     Worcester
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     43,782
#    </td>
#    <td>
#     29.7 sq mi (76.92 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     28.9 sq mi (74.85 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1740
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Beverly,_Massachusetts" title="Beverly, Massachusetts">
#      <b>
#       Beverly
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     42,670
#    </td>
#    <td>
#     22.6 sq mi (58.53 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     15.1 sq mi (39.11 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1668
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Billerica,_Massachusetts" title="Billerica, Massachusetts">
#      <b>
#       Billerica
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     42,119
#    </td>
#    <td>
#     26.4 sq mi (68.38 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     25.9 sq mi (67.08 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1655
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Fitchburg,_Massachusetts" title="Fitchburg, Massachusetts">
#      <b>
#       Fitchburg
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Worcester">
#     Worcester
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     41,946
#    </td>
#    <td>
#     28.1 sq mi (72.78 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     27.8 sq mi (72.00 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1764
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Marlborough,_Massachusetts" title="Marlborough, Massachusetts">
#      <b>
#       Marlborough
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     41,793
#    </td>
#    <td>
#     22.1 sq mi (57.24 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.9 sq mi (54.13 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1660
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Woburn,_Massachusetts" title="Woburn, Massachusetts">
#      <b>
#       Woburn
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     40,876
#    </td>
#    <td>
#     12.9 sq mi (33.41 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     12.7 sq mi (32.89 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1642
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westfield,_Massachusetts" title="Westfield, Massachusetts">
#      <b>
#       Westfield
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampden">
#     Hampden
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     40,834
#    </td>
#    <td>
#     47.3 sq mi (122.51 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     46.3 sq mi (119.92 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1669
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chelsea,_Massachusetts" title="Chelsea, Massachusetts">
#      <b>
#       Chelsea
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Suffolk">
#     Suffolk
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td>
#     40,787
#    </td>
#    <td>
#     2.5 sq mi (6.47 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     2.2 sq mi (5.70 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1739
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Amherst,_Massachusetts" title="Amherst, Massachusetts">
#      <b>
#       Amherst
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampshire">
#     Hampshire
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td>
#     39,263
#    </td>
#    <td>
#     27.7 sq mi (71.74 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     27.6 sq mi (71.48 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Braintree,_Massachusetts" title="Braintree, Massachusetts">
#      <b>
#       Braintree
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     39,143
#    </td>
#    <td>
#     14.6 sq mi (37.81 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     13.8 sq mi (35.74 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1640
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Shrewsbury,_Massachusetts" title="Shrewsbury, Massachusetts">
#      <b>
#       Shrewsbury
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Worcester">
#     Worcester
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     38,325
#    </td>
#    <td>
#     21.7 sq mi (56.20 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.7 sq mi (53.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1727
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Holyoke,_Massachusetts" title="Holyoke, Massachusetts">
#      <b>
#       Holyoke
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampden">
#     Hampden
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     38,238
#    </td>
#    <td>
#     22.8 sq mi (59.05 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     21.2 sq mi (54.91 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1850
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Natick,_Massachusetts" title="Natick, Massachusetts">
#      <b>
#       Natick
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     37,006
#    </td>
#    <td>
#     16.1 sq mi (41.70 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     15.1 sq mi (39.11 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1781
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Andover,_Massachusetts" title="Andover, Massachusetts">
#      <b>
#       Andover
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     36,569
#    </td>
#    <td>
#     32.1 sq mi (83.14 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     31.0 sq mi (80.29 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1646
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chelmsford,_Massachusetts" title="Chelmsford, Massachusetts">
#      <b>
#       Chelmsford
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     36,392
#    </td>
#    <td>
#     23.2 sq mi (60.09 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     22.7 sq mi (58.79 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1655
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Watertown,_Massachusetts" title="Watertown, Massachusetts">
#      <b>
#       Watertown
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td>
#     35,329
#    </td>
#    <td>
#     4.1 sq mi (10.62 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     4.0 sq mi (10.36 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1630
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Randolph,_Massachusetts" title="Randolph, Massachusetts">
#      <b>
#       Randolph
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td>
#     34,984
#    </td>
#    <td>
#     10.5 sq mi (27.19 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     10.1 sq mi (26.16 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1793
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Lexington,_Massachusetts" title="Lexington, Massachusetts">
#      <b>
#       Lexington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     34,454
#    </td>
#    <td>
#     16.5 sq mi (42.73 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     16.4 sq mi (42.48 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1713
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dartmouth,_Massachusetts" title="Dartmouth, Massachusetts">
#      <b>
#       Dartmouth
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Bristol">
#     Bristol
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     33,783
#    </td>
#    <td>
#     97.5 sq mi (252.52 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     60.9 sq mi (157.73 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1664
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Franklin,_Massachusetts" title="Franklin, Massachusetts">
#      <b>
#       Franklin
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Administrator-Council
#    </td>
#    <td>
#     33,261
#    </td>
#    <td>
#     27.0 sq mi (69.93 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     26.6 sq mi (68.89 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1778
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dracut,_Massachusetts" title="Dracut, Massachusetts">
#      <b>
#       Dracut
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     32,617
#    </td>
#    <td>
#     21.4 sq mi (55.43 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.9 sq mi (54.13 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1701
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Falmouth,_Massachusetts" title="Falmouth, Massachusetts">
#      <b>
#       Falmouth
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Barnstable">
#     Barnstable
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     32,517
#    </td>
#    <td>
#     54.4 sq mi (140.90 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     44.1 sq mi (114.22 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1686
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Needham,_Massachusetts" title="Needham, Massachusetts">
#      <b>
#       Needham
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     32,091
#    </td>
#    <td>
#     12.7 sq mi (32.89 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     12.6 sq mi (32.63 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1711
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Norwood,_Massachusetts" title="Norwood, Massachusetts">
#      <b>
#       Norwood
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     31,611
#    </td>
#    <td>
#     10.6 sq mi (27.45 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     10.5 sq mi (27.19 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1872
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Tewksbury,_Massachusetts" title="Tewksbury, Massachusetts">
#      <b>
#       Tewksbury
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     31,342
#    </td>
#    <td>
#     21.1 sq mi (54.65 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.7 sq mi (53.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1734
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/North_Andover,_Massachusetts" title="North Andover, Massachusetts">
#      <b>
#       North Andover
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     30,915
#    </td>
#    <td>
#     27.8 sq mi (72.00 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     26.3 sq mi (68.12 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1855
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/North_Attleborough,_Massachusetts" title="North Attleborough, Massachusetts">
#      <b>
#       North Attleborough
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Bristol">
#     Bristol
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td>
#     30,834
#    </td>
#    <td>
#     19.1 sq mi (49.47 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     18.6 sq mi (48.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1887
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Milford,_Massachusetts" title="Milford, Massachusetts">
#      <b>
#       Milford
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Worcester">
#     Worcester
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     30,379
#    </td>
#    <td>
#     14.9 sq mi (38.59 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     14.6 sq mi (37.81 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1780
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Melrose,_Massachusetts" title="Melrose, Massachusetts">
#      <b>
#       Melrose
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     29,817
#    </td>
#    <td>
#     4.8 sq mi (12.43 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     4.7 sq mi (12.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1850
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Gloucester,_Massachusetts" title="Gloucester, Massachusetts">
#      <b>
#       Gloucester
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     29,729
#    </td>
#    <td>
#     41.5 sq mi (107.48 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     26.2 sq mi (67.86 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1623
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Northampton,_Massachusetts" title="Northampton, Massachusetts">
#      <b>
#       Northampton
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampshire">
#     <a href="/wiki/Hampshire_County,_Massachusetts" title="Hampshire County, Massachusetts">
#      Hampshire
#     </a>
#     (seat)
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     29,571
#    </td>
#    <td>
#     35.8 sq mi (92.72 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     34.2 sq mi (88.58 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1654
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wellesley,_Massachusetts" title="Wellesley, Massachusetts">
#      <b>
#       Wellesley
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     29,550
#    </td>
#    <td>
#     10.5 sq mi (27.19 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     10.2 sq mi (26.42 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1881
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Stoughton,_Massachusetts" title="Stoughton, Massachusetts">
#      <b>
#       Stoughton
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     29,281
#    </td>
#    <td>
#     16.3 sq mi (42.22 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     16.0 sq mi (41.44 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1726
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Springfield,_Massachusetts" title="West Springfield, Massachusetts">
#      <b>
#       West Springfield
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampden">
#     Hampden
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     28,835
#    </td>
#    <td>
#     17.5 sq mi (45.32 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     16.7 sq mi (43.25 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1774
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Agawam,_Massachusetts" title="Agawam, Massachusetts">
#      <b>
#       Agawam
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Hampden">
#     Hampden
#    </td>
#    <td>
#     Mayor-Council
#    </td>
#    <td>
#     28,692
#    </td>
#    <td>
#     24.3 sq mi (62.94 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     23.3 sq mi (60.35 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1855
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Bridgewater,_Massachusetts" title="Bridgewater, Massachusetts">
#      <b>
#       Bridgewater
#      </b>
#     </a>
#    </td>
#    <td data-sort-value="City">
#     City
#    </td>
#    <td data-sort-value="Plymouth">
#     Plymouth
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td>
#     28,633
#    </td>
#    <td>
#     28.2 sq mi (73.04 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     27.5 sq mi (71.22 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1656
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Milton,_Massachusetts" title="Milton, Massachusetts">
#      <b>
#       Milton
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     28,630
#    </td>
#    <td>
#     13.3 sq mi (34.45 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     13.0 sq mi (33.67 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1662
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Saugus,_Massachusetts" title="Saugus, Massachusetts">
#      <b>
#       Saugus
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     28,619
#    </td>
#    <td>
#     11.8 sq mi (30.56 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     10.8 sq mi (27.97 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1815
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Danvers,_Massachusetts" title="Danvers, Massachusetts">
#      <b>
#       Danvers
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Essex">
#     Essex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     28,087
#    </td>
#    <td>
#     14.1 sq mi (36.52 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     13.3 sq mi (34.45 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Belmont,_Massachusetts" title="Belmont, Massachusetts">
#      <b>
#       Belmont
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     27,295
#    </td>
#    <td>
#     4.7 sq mi (12.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     4.7 sq mi (12.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1859
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wakefield,_Massachusetts" title="Wakefield, Massachusetts">
#      <b>
#       Wakefield
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     27,090
#    </td>
#    <td>
#     7.9 sq mi (20.46 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     7.5 sq mi (19.42 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1812
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Walpole,_Massachusetts" title="Walpole, Massachusetts">
#      <b>
#       Walpole
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     26,383
#    </td>
#    <td>
#     21.0 sq mi (54.39 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.5 sq mi (53.09 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1724
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Burlington,_Massachusetts" title="Burlington, Massachusetts">
#      <b>
#       Burlington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     26,377
#    </td>
#    <td>
#     11.9 sq mi (30.82 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     11.8 sq mi (30.56 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1799
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Marshfield,_Massachusetts" title="Marshfield, Massachusetts">
#      <b>
#       Marshfield
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Plymouth">
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     25,825
#    </td>
#    <td>
#     31.7 sq mi (82.10 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     28.5 sq mi (73.81 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1640
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Reading,_Massachusetts" title="Reading, Massachusetts">
#      <b>
#       Reading
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     25,518
#    </td>
#    <td>
#     9.9 sq mi (25.64 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     9.9 sq mi (25.64 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1644
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dedham,_Massachusetts" title="Dedham, Massachusetts">
#      <b>
#       Dedham
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     <a href="/wiki/Norfolk_County,_Massachusetts" title="Norfolk County, Massachusetts">
#      Norfolk
#     </a>
#     (seat)
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     25,364
#    </td>
#    <td>
#     10.6 sq mi (27.45 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     10.5 sq mi (27.19 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1636
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Easton,_Massachusetts" title="Easton, Massachusetts">
#      <b>
#       Easton
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Bristol">
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     25,058
#    </td>
#    <td>
#     29.2 sq mi (75.63 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     28.4 sq mi (73.56 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1725
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Yarmouth,_Massachusetts" title="Yarmouth, Massachusetts">
#      <b>
#       Yarmouth
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Barnstable">
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     25,023
#    </td>
#    <td>
#     28.2 sq mi (73.04 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     24.1 sq mi (62.42 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1639
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westford,_Massachusetts" title="Westford, Massachusetts">
#      <b>
#       Westford
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     24,643
#    </td>
#    <td>
#     31.3 sq mi (81.07 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     30.6 sq mi (79.25 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1729
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Canton,_Massachusetts" title="Canton, Massachusetts">
#      <b>
#       Canton
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Norfolk">
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     24,370
#    </td>
#    <td>
#     19.6 sq mi (50.76 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     18.9 sq mi (48.95 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1797
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hingham,_Massachusetts" title="Hingham, Massachusetts">
#      <b>
#       Hingham
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Plymouth">
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     24,284
#    </td>
#    <td>
#     26.3 sq mi (68.12 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     22.2 sq mi (57.50 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1635
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Middleborough,_Massachusetts" title="Middleborough, Massachusetts">
#      <b>
#       Middleborough
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Plymouth">
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     24,245
#    </td>
#    <td>
#     72.2 sq mi (187.00 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     69.1 sq mi (178.97 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1669
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Acton,_Massachusetts" title="Acton, Massachusetts">
#      <b>
#       Acton
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     24,021
#    </td>
#    <td>
#     20.3 sq mi (52.58 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.0 sq mi (51.80 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1735
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Mansfield,_Massachusetts" title="Mansfield, Massachusetts">
#      <b>
#       Mansfield
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Bristol">
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     23,860
#    </td>
#    <td>
#     20.7 sq mi (53.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.5 sq mi (53.09 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wilmington,_Massachusetts" title="Wilmington, Massachusetts">
#      <b>
#       Wilmington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     23,349
#    </td>
#    <td>
#     17.2 sq mi (44.55 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     17.1 sq mi (44.29 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1730
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wareham,_Massachusetts" title="Wareham, Massachusetts">
#      <b>
#       Wareham
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Plymouth">
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     23,303
#    </td>
#    <td>
#     46.3 sq mi (119.92 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     35.8 sq mi (92.72 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1739
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Stoneham,_Massachusetts" title="Stoneham, Massachusetts">
#      <b>
#       Stoneham
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     23,244
#    </td>
#    <td>
#     6.7 sq mi (17.35 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     6.2 sq mi (16.06 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1725
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Winchester,_Massachusetts" title="Winchester, Massachusetts">
#      <b>
#       Winchester
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Middlesex">
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td>
#     22,970
#    </td>
#    <td>
#     6.3 sq mi (16.32 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     6.0 sq mi (15.54 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1850
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westborough,_Massachusetts" title="Westborough, Massachusetts">
#      <b>
#       Westborough
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Worcester">
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     21,567
#    </td>
#    <td>
#     21.6 sq mi (55.94 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.5 sq mi (53.09 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1717
#    </td>
#   </tr>
#   <tr>
#    <td>
# ...
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     19 sq mi (49.21 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1714
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Petersham,_Massachusetts" title="Petersham, Massachusetts">
#      <b>
#       Petersham
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Worcester">
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     1,194
#    </td>
#    <td>
#     68.3 sq mi (176.90 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     54.2 sq mi (140.38 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1754
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Worthington,_Massachusetts" title="Worthington, Massachusetts">
#      <b>
#       Worthington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampshire">
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     1,193
#    </td>
#    <td>
#     32.1 sq mi (83.14 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     31.9 sq mi (82.62 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1768
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chesterfield,_Massachusetts" title="Chesterfield, Massachusetts">
#      <b>
#       Chesterfield
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampshire">
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     1,186
#    </td>
#    <td>
#     31.2 sq mi (80.81 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     30.8 sq mi (79.77 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1762
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Charlemont,_Massachusetts" title="Charlemont, Massachusetts">
#      <b>
#       Charlemont
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     1,185
#    </td>
#    <td>
#     26.4 sq mi (68.38 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     25.9 sq mi (67.08 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1765
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Monterey,_Massachusetts" title="Monterey, Massachusetts">
#      <b>
#       Monterey
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     1,095
#    </td>
#    <td>
#     27.4 sq mi (70.97 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     26.4 sq mi (68.38 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1847
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/New_Braintree,_Massachusetts" title="New Braintree, Massachusetts">
#      <b>
#       New Braintree
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Worcester">
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     996
#    </td>
#    <td>
#     20.9 sq mi (54.13 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     20.7 sq mi (53.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Sandisfield,_Massachusetts" title="Sandisfield, Massachusetts">
#      <b>
#       Sandisfield
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     989
#    </td>
#    <td>
#     53.0 sq mi (137.27 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     51.8 sq mi (134.16 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1762
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/New_Salem,_Massachusetts" title="New Salem, Massachusetts">
#      <b>
#       New Salem
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     983
#    </td>
#    <td>
#     58.6 sq mi (151.77 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     44.8 sq mi (116.03 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Goshen,_Massachusetts" title="Goshen, Massachusetts">
#      <b>
#       Goshen
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampshire">
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     970
#    </td>
#    <td>
#     17.7 sq mi (45.84 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     17.4 sq mi (45.07 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1781
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wendell,_Massachusetts" title="Wendell, Massachusetts">
#      <b>
#       Wendell
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     924
#    </td>
#    <td>
#     32.2 sq mi (83.40 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     31.9 sq mi (82.62 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1781
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Windsor,_Massachusetts" title="Windsor, Massachusetts">
#      <b>
#       Windsor
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     831
#    </td>
#    <td>
#     35.2 sq mi (91.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     35.0 sq mi (90.65 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1771
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Cummington,_Massachusetts" title="Cummington, Massachusetts">
#      <b>
#       Cummington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampshire">
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     829
#    </td>
#    <td>
#     23.1 sq mi (59.83 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     22.9 sq mi (59.31 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1779
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Montgomery,_Massachusetts" title="Montgomery, Massachusetts">
#      <b>
#       Montgomery
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampden">
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     819
#    </td>
#    <td>
#     15.2 sq mi (39.37 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     15.1 sq mi (39.11 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1780
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Peru,_Massachusetts" title="Peru, Massachusetts">
#      <b>
#       Peru
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     814
#    </td>
#    <td>
#     26.0 sq mi (67.34 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     25.9 sq mi (67.08 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1771
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Warwick,_Massachusetts" title="Warwick, Massachusetts">
#      <b>
#       Warwick
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     780
#    </td>
#    <td>
#     37.6 sq mi (97.38 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     37.3 sq mi (96.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1763
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hancock,_Massachusetts" title="Hancock, Massachusetts">
#      <b>
#       Hancock
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     757
#    </td>
#    <td>
#     35.8 sq mi (92.72 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     35.7 sq mi (92.46 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1776
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Leyden,_Massachusetts" title="Leyden, Massachusetts">
#      <b>
#       Leyden
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     734
#    </td>
#    <td>
#     18.0 sq mi (46.62 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     17.9 sq mi (46.36 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1809
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Heath,_Massachusetts" title="Heath, Massachusetts">
#      <b>
#       Heath
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     723
#    </td>
#    <td>
#     24.9 sq mi (64.49 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     24.9 sq mi (64.49 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1785
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Florida,_Massachusetts" title="Florida, Massachusetts">
#      <b>
#       Florida
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     694
#    </td>
#    <td>
#     24.6 sq mi (63.71 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     24.4 sq mi (63.20 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1805
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Savoy,_Massachusetts" title="Savoy, Massachusetts">
#      <b>
#       Savoy
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     645
#    </td>
#    <td>
#     36.0 sq mi (93.24 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     35.8 sq mi (92.72 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1797
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Plainfield,_Massachusetts" title="Plainfield, Massachusetts">
#      <b>
#       Plainfield
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampshire">
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     633
#    </td>
#    <td>
#     21.3 sq mi (55.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     21.1 sq mi (54.65 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1807
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Washington,_Massachusetts" title="Washington, Massachusetts">
#      <b>
#       Washington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     494
#    </td>
#    <td>
#     38.8 sq mi (100.49 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     38 sq mi (98.42 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1777
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Alford,_Massachusetts" title="Alford, Massachusetts">
#      <b>
#       Alford
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     486
#    </td>
#    <td>
#     11.5 sq mi (29.78 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     11.5 sq mi (29.78 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1773
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Tolland,_Massachusetts" title="Tolland, Massachusetts">
#      <b>
#       Tolland
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampden">
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     471
#    </td>
#    <td>
#     32.8 sq mi (84.95 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     31.5 sq mi (81.58 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1810
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Aquinnah,_Massachusetts" title="Aquinnah, Massachusetts">
#      <b>
#       Aquinnah
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Dukes">
#     Dukes
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     439
#    </td>
#    <td>
#     40.8 sq mi (105.67 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     5.4 sq mi (13.99 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1870
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Tyringham,_Massachusetts" title="Tyringham, Massachusetts">
#      <b>
#       Tyringham
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     427
#    </td>
#    <td>
#     18.9 sq mi (48.95 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     18.6 sq mi (48.17 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1762
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Rowe,_Massachusetts" title="Rowe, Massachusetts">
#      <b>
#       Rowe
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     424
#    </td>
#    <td>
#     24.0 sq mi (62.16 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     23.4 sq mi (60.61 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1785
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Middlefield,_Massachusetts" title="Middlefield, Massachusetts">
#      <b>
#       Middlefield
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Hampshire">
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     385
#    </td>
#    <td>
#     24.2 sq mi (62.68 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     24.2 sq mi (62.68 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1783
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hawley,_Massachusetts" title="Hawley, Massachusetts">
#      <b>
#       Hawley
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     353
#    </td>
#    <td>
#     30.9 sq mi (80.03 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     30.9 sq mi (80.03 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1792
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/New_Ashford,_Massachusetts" title="New Ashford, Massachusetts">
#      <b>
#       New Ashford
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     250
#    </td>
#    <td>
#     13.5 sq mi (34.96 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     13.4 sq mi (34.71 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1835
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Mount_Washington,_Massachusetts" title="Mount Washington, Massachusetts">
#      <b>
#       Mount Washington
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Berkshire">
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     160
#    </td>
#    <td>
#     22.4 sq mi (58.02 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     22.2 sq mi (57.50 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1779
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Monroe,_Massachusetts" title="Monroe, Massachusetts">
#      <b>
#       Monroe
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Franklin">
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     118
#    </td>
#    <td>
#     10.8 sq mi (27.97 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     10.7 sq mi (27.71 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1822
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Gosnold,_Massachusetts" title="Gosnold, Massachusetts">
#      <b>
#       Gosnold
#      </b>
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td data-sort-value="Dukes">
#     Dukes
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td>
#     70
#    </td>
#    <td>
#     140.2 sq mi (363.12 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     13.2 sq mi (34.19 km
#     <sup>
#      2
#     </sup>
#     )
#    </td>
#    <td>
#     1864
#    </td>
#   </tr>
#  </tbody>
# </table>

# %% [markdown]
# Excellent! Now we just need to pull out the data from the rows and columns of that table. Notice that there are 6 columns, each `row` is contained in a `<tr>` element (which stands for `table row`), and inside each row there is a `<td>` element for each entry. That's what we want, so let's loop through them:

# %%
import re # Might need to do some pattern matching with regular expressions

# Open a file to store the data
f = open('output.csv', 'w')
 
# First grab the headers
t_headers = []
for th in table.find_all("th"):
        # remove any references in square brackets and extra spaces from left and right
        t_headers.append(re.sub('\[.*?\]', '', th.text).strip())

f.write(",".join(t_headers) + "\n")
    
# Loop over each row in the table
for row in table.findAll("tr"):
    
    # Find all the cells in the row
    cells = row.findAll("td")
    
    # If the row is complete (i.e. there are 7 cells)
    #    assign the value in each cell to the appropriate variable.
    if len(cells) == 7:
        
        Municipality = cells[0].find(text = True)
        
        Type = cells[1].find(text = True)
        
        County = cells[2].find(text = True)
        
        Form_of_government = cells[3].find(text = True)
        
        # This cell sometimes has a comma in it, let's get rid opf that while we're here
        Population = cells[4].find(text = True).replace(',', '')
        
        Area = cells[5].find(text = True)
        
        Year_est = cells[6].find(text = True)
 
        # Concatenate all the cells together, separated by commas
        line = Municipality  + "," + Type + "," + County + "," + Form_of_government + "," + Population + "," + Area + "," + Year_est + "\n"
        
        # Append the line to the file
        f.write(line)
        
# Clean up when we're done
f.close()

# %% [markdown]
# ## And there you have it! You're ready to wrangle some data of your own.
