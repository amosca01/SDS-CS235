# %% [markdown]
# # Introduction to Pandas: the Python Data Analysis library
# This is a short introduction to pandas, geared mainly for new users and adapted heavily from the "10 Minutes to Pandas" tutorial from http://pandas.pydata.org. You can see more complex recipes in the Pandas Cookbook: http://pandas.pydata.org/pandas-docs/stable/cookbook.html
# ## Initial setup
# Let's start by importing 2 useful libraries: `pandas` and `numpy`

# %%
import pandas, numpy

# %% [markdown]
# You can create a `Series` by passing a list of values. By default, `pandas` will create an integer index.

# %%
s = pandas.Series([1,3,5,"CSC is awesome",8])
s
# Out:
# 0                 1
# 1                 3
# 2                 5
# 3    CSC is awesome
# 4                 8
# dtype: object

# %% [markdown]
# You can also use `pandas` to create an series of `datetime` objects. Let's make one for the week beginning March 1st, 2021:

# %%
dates = pandas.date_range('20210301',
                          periods = 7)
dates
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06', '2021-03-07'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Now we'll create a `DataFrame` using the `dates` array as our index, fill it with some random values using `numpy`, and give the columns some labels.

# %%
df = pandas.DataFrame(numpy.random.randn(7,4), 
                      index = dates, 
                      columns = {'dog','cat','mouse','duck'})
df
# Out:
#                 duck       dog     mouse       cat
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511
# 2021-03-02  0.625096  0.032916  0.576003  1.627850
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162
# 2021-03-06 -0.157407  0.044297  0.974831 -0.098350
# 2021-03-07  0.651588  2.436893 -2.024332 -0.356716

# %% [markdown]
# It can also be useful to know how to create a `DataFrame` from a `dict` of objects. This comes in particularly handy when working with JSON-like structures.

# %%
df2 = pandas.DataFrame({ 'A' : 1.,
                     'B' : pandas.Timestamp('20130102'),
                     'C' : pandas.Series(1,index=list(range(5)),dtype='float32'),
                     'D' : numpy.array([3] * 5
                                    ,dtype='int32'),
                     'E' : pandas.Categorical(["test","train","blah","train","blah"]),
                     'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   blah  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# 4  1.0 2013-01-02  1.0  3   blah  foo

# %% [markdown]
# ## Exploring the data in a DataFrame
# We can access the data types of each column in a `DataFrame` as follows:

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# We can display the `index`, `columns`, and the underlying `numpy values` separately:

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.values
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'blah', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'blah', 'foo']],
#       dtype=object)

# %% [markdown]
# To get a quick statistical summary of your data, use the `.describe()` method:

# %%
df2.describe()
# Out:
#          A    C    D
# count  5.0  5.0  5.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %% [markdown]
# ## Some basic data transformations
# `DataFrames` have a built-in transpose:

# %%
df.T
# Out:
#        2021-03-01  2021-03-02  2021-03-03  2021-03-04  2021-03-05  2021-03-06  \
# duck    -0.001297    0.625096   -0.877032   -0.002861    0.380730   -0.157407
# dog      1.899001    0.032916    1.310729   -1.283193   -1.773959    0.044297
# mouse   -0.667751    0.576003    0.232789   -1.400491    0.702624    0.974831
# cat      0.040511    1.627850    1.463413    0.203341   -0.098162   -0.098350
#
#        2021-03-07
# duck     0.651588
# dog      2.436893
# mouse   -2.024332
# cat     -0.356716

# %% [markdown]
# We can also sort a `DataFrame` along a given data dimension. For example, we might want to `sort` by the values in the `duck` column:

# %%
df.sort_values(by = "cat")
# Out:
#                 duck       dog     mouse       cat
# 2021-03-07  0.651588  2.436893 -2.024332 -0.356716
# 2021-03-06 -0.157407  0.044297  0.974831 -0.098350
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413
# 2021-03-02  0.625096  0.032916  0.576003  1.627850

# %% [markdown]
# We can also sort the rows `(axis=0)` and columns `(axis=1)` by their index/header values:

# %%
df.sort_index(axis = 0, 
              ascending = False)
# Out:
#                 duck       dog     mouse       cat
# 2021-03-07  0.651588  2.436893 -2.024332 -0.356716
# 2021-03-06 -0.157407  0.044297  0.974831 -0.098350
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413
# 2021-03-02  0.625096  0.032916  0.576003  1.627850
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511

# %%
df.sort_index(axis = 1)
# Out:
#                  cat       dog      duck     mouse
# 2021-03-01  0.040511  1.899001 -0.001297 -0.667751
# 2021-03-02  1.627850  0.032916  0.625096  0.576003
# 2021-03-03  1.463413  1.310729 -0.877032  0.232789
# 2021-03-04  0.203341 -1.283193 -0.002861 -1.400491
# 2021-03-05 -0.098162 -1.773959  0.380730  0.702624
# 2021-03-06 -0.098350  0.044297 -0.157407  0.974831
# 2021-03-07 -0.356716  2.436893  0.651588 -2.024332

# %% [markdown]
# ## Selection
# To see only only the first few rows of a `DataFrame`, use the `.head()` function:

# %%
df.head()
# Out:
#                 duck       dog     mouse       cat
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511
# 2021-03-02  0.625096  0.032916  0.576003  1.627850
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162

# %% [markdown]
# To view only the last few rows, use the `.tail()` function. Note that by default, both `.head()` and `.tail()`$ return 5 rows. You can also specify the number you want by passing in an integer.

# %%
df.tail(3)
# Out:
#                 duck       dog     mouse       cat
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162
# 2021-03-06 -0.157407  0.044297  0.974831 -0.098350
# 2021-03-07  0.651588  2.436893 -2.024332 -0.356716

# %% [markdown]
# Selecting a single column via indexing yields a `Series`:

# %%
df2['A'] # a lot like df$A in R
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: A, dtype: float64

# %% [markdown]
# We can also select a subset of the rows using slicing. You can select either by integer indexing:

# %%
df[2:5]
# Out:
#                 duck       dog     mouse       cat
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162

# %% [markdown]
# To select more than one column at a time, try `.loc[]`:

# %%
df.loc[:, ['cat', 'dog']]
# Out:
#                  cat       dog
# 2021-03-01  0.040511  1.899001
# 2021-03-02  1.627850  0.032916
# 2021-03-03  1.463413  1.310729
# 2021-03-04  0.203341 -1.283193
# 2021-03-05 -0.098162 -1.773959
# 2021-03-06 -0.098350  0.044297
# 2021-03-07 -0.356716  2.436893

# %% [markdown]
# And of course, you might want to do both at the same time:

# %%
df.loc['20210302':'20210305', ['cat', 'duck']]
# Out:
#                  cat      duck
# 2021-03-02  1.627850  0.625096
# 2021-03-03  1.463413 -0.877032
# 2021-03-04  0.203341 -0.002861
# 2021-03-05 -0.098162  0.380730

# %% [markdown]
# ## Boolean Indexing
# Sometimes it's useful to be able to select all rows that meet some criteria. For example, we might want all rows where the value in the `cat` column is greater than 0:

# %%
df[df['cat'] > 0]
# Out:
#                 duck       dog     mouse       cat
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511
# 2021-03-02  0.625096  0.032916  0.576003  1.627850
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341

# %% [markdown]
# Or perhaps we'd like to eliminate all negative values:

# %%
nonneg = df[df > 0]
nonneg
# Out:
#                 duck       dog     mouse       cat
# 2021-03-01       NaN  1.899001       NaN  0.040511
# 2021-03-02  0.625096  0.032916  0.576003  1.627850
# 2021-03-03       NaN  1.310729  0.232789  1.463413
# 2021-03-04       NaN       NaN       NaN  0.203341
# 2021-03-05  0.380730       NaN  0.702624       NaN
# 2021-03-06       NaN  0.044297  0.974831       NaN
# 2021-03-07  0.651588  2.436893       NaN       NaN

# %% [markdown]
# And then maybe we'd like to drop all the rows with missing values:

# %%
nonneg.dropna()
# Out:
#                 duck       dog     mouse      cat
# 2021-03-02  0.625096  0.032916  0.576003  1.62785

# %% [markdown]
# Oops... maybe not. How about we set them to 0 instead?

# %%
nonneg.fillna(value = 0)
# Out:
#                 duck       dog     mouse       cat
# 2021-03-01  0.000000  1.899001  0.000000  0.040511
# 2021-03-02  0.625096  0.032916  0.576003  1.627850
# 2021-03-03  0.000000  1.310729  0.232789  1.463413
# 2021-03-04  0.000000  0.000000  0.000000  0.203341
# 2021-03-05  0.380730  0.000000  0.702624  0.000000
# 2021-03-06  0.000000  0.044297  0.974831  0.000000
# 2021-03-07  0.651588  2.436893  0.000000  0.000000

# %% [markdown]
# But what if your values aren't numeric? No problem, we can also do filtering. First, let's copy the `DataFrame` and add a new column of nominal values:

# %%
df3 = df.copy()
df3['color'] = ['blue', 'green','red','blue','green','red','blue']
df3
# Out:
#                 duck       dog     mouse       cat  color
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511   blue
# 2021-03-02  0.625096  0.032916  0.576003  1.627850  green
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413    red
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341   blue
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162  green
# 2021-03-06 -0.157407  0.044297  0.974831 -0.098350    red
# 2021-03-07  0.651588  2.436893 -2.024332 -0.356716   blue

# %% [markdown]
# Now we can use the `.isin()` function to select only the rows with `green` or `blue` in the `color` column:

# %%
df3[df3['color'] == 'green']
# Out:
#                 duck       dog     mouse       cat  color
# 2021-03-02  0.625096  0.032916  0.576003  1.627850  green
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162  green

# %%
df3 # Note that none of the filtering operations change the original DataFrame
# Out:
#                 duck       dog     mouse       cat  color
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511   blue
# 2021-03-02  0.625096  0.032916  0.576003  1.627850  green
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413    red
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341   blue
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162  green
# 2021-03-06 -0.157407  0.044297  0.974831 -0.098350    red
# 2021-03-07  0.651588  2.436893 -2.024332 -0.356716   blue

# %% [markdown]
# ## Prefer something more like `dplyr`?
# The `dfply` module provided dplyr-style piping operations for `pandas DataFrames`, along with many familiar verbs. Note that `>>` is the `dfply` equivalent of `%>%`, and `X` represents the piped `DataFrame`.
#
# ### `select()`

# %%
from dfply import *
df2 >> select("A")
# Out:
#      A
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %% [markdown]
# Just be careful about python and spacing:

# %%
# Broken
# df2 >> 
#    select(X.A)
    
# If you want to indent, you need parens
(
df2 >> 
   select(X.A)
)
# Out:
#      A
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %% [markdown]
# ### Dropping columns with `drop()` or `select()`
#
# `drop()` is a helper function that does the opposite of `select()`:

# %%
(df2 >> 
   drop(X.E, X.F))
# Out:
#      A          B    C  D
# 0  1.0 2013-01-02  1.0  3
# 1  1.0 2013-01-02  1.0  3
# 2  1.0 2013-01-02  1.0  3
# 3  1.0 2013-01-02  1.0  3
# 4  1.0 2013-01-02  1.0  3

# %% [markdown]
# You can also use `select()` along with the `~` (which means "not") to drop unwanted columns:

# %%
(df2 >> 
   select(~X.E, ~X.F))
# Out:
#      A          B    C  D
# 0  1.0 2013-01-02  1.0  3
# 1  1.0 2013-01-02  1.0  3
# 2  1.0 2013-01-02  1.0  3
# 3  1.0 2013-01-02  1.0  3
# 4  1.0 2013-01-02  1.0  3

# %% [markdown]
# ### Filtering with `mask()`
# `mask()` keeps all the rows where the criteria is/are true:

# %%
# this is just like filter() in R
(df3 >>
   mask(X.color.isin(['green','blue']), X.cat > 0))
# Out:
#                 duck       dog     mouse       cat  color
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511   blue
# 2021-03-02  0.625096  0.032916  0.576003  1.627850  green
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341   blue

# %% [markdown]
# ### Add new columns with `mutate()`

# %%
(df3 >>
   mutate(platypus = (X.cat + X.duck)/2))
# Out:
#                 duck       dog     mouse       cat  color  platypus
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511   blue  0.019607
# 2021-03-02  0.625096  0.032916  0.576003  1.627850  green  1.126473
# 2021-03-03 -0.877032  1.310729  0.232789  1.463413    red  0.293190
# 2021-03-04 -0.002861 -1.283193 -1.400491  0.203341   blue  0.100240
# 2021-03-05  0.380730 -1.773959  0.702624 -0.098162  green  0.141284
# 2021-03-06 -0.157407  0.044297  0.974831 -0.098350    red -0.127878
# 2021-03-07  0.651588  2.436893 -2.024332 -0.356716   blue  0.147436

# %% [markdown]
# ## Basic Math
# Helper methods on the `DataFrame` object make it straightforward to calculate things like the `.mean()` across all numeric columns:

# %%
df.mean(axis = 0)
# Out:
# duck     0.088402
# dog      0.380955
# mouse   -0.229475
# cat      0.397412
# dtype: float64

# %% [markdown]
# We can also perform the same operation on individual rows:

# %%
df.mean(axis = 1)
# Out:
# 2021-03-01    0.317616
# 2021-03-02    0.715466
# 2021-03-03    0.532475
# 2021-03-04   -0.620801
# 2021-03-05   -0.197192
# 2021-03-06    0.190843
# 2021-03-07    0.176858
# Freq: D, dtype: float64

# %% [markdown]
# `.median()` also behaves as expected:

# %%
df.median(axis = 0)
# Out:
# duck    -0.001297
# dog      0.044297
# mouse    0.232789
# cat      0.040511
# dtype: float64

# %% [markdown]
# No helper function for what you need? No problem. You can also use the `.apply()` function to evaluate functions to the data. For example, we might want to perform a cumulative summation (thanks, `numpy`!):

# %%
df.apply(numpy.cumsum)
# Out:
#                 duck       dog     mouse       cat
# 2021-03-01 -0.001297  1.899001 -0.667751  0.040511
# 2021-03-02  0.623800  1.931917 -0.091749  1.668361
# 2021-03-03 -0.253233  3.242646  0.141040  3.131774
# 2021-03-04 -0.256094  1.959452 -1.259451  3.335115
# 2021-03-05  0.124636  0.185493 -0.556827  3.236954
# 2021-03-06 -0.032771  0.229791  0.418004  3.138604
# 2021-03-07  0.618817  2.666684 -1.606327  2.781887

# %% [markdown]
# Or apply your own function, such as finding the spread (`max` value - `min` value):

# %%
df.apply(lambda x: x.max() - x.min(), axis = 0)
# Out:
# duck     1.528621
# dog      4.210853
# mouse    2.999163
# cat      1.984566
# dtype: float64

# %% [markdown]
# ## Combining DataFrames
# Combining `DataFrame` objects can be done using simple concatenation (provided they have the same columns):

# %%
frame_one = pandas.DataFrame(numpy.random.randn(5, 4))
frame_one
# Out:
#           0         1         2         3
# 0  1.568494  0.398953  0.522460 -0.601093
# 1  2.519302 -0.200940  0.349901 -0.794343
# 2  0.425372 -0.152015 -0.527282 -1.245129
# 3 -0.177185  0.108276 -0.130570 -1.713837
# 4  2.364708 -0.261616 -0.041494  0.941653

# %%
frame_two = pandas.DataFrame(numpy.random.randn(5, 4))
frame_two
# Out:
#           0         1         2         3
# 0 -0.209179 -0.326375  0.440166 -0.590773
# 1 -0.674814 -0.286429 -1.083910  0.730554
# 2 -2.049614 -0.767186 -2.532260 -0.988238
# 3 -0.799530  0.584514 -0.807622  0.101311
# 4 -0.095490 -0.078373  0.604457 -0.119861

# %%
pandas.concat([frame_one, frame_two])
# Out:
#           0         1         2         3
# 0  1.568494  0.398953  0.522460 -0.601093
# 1  2.519302 -0.200940  0.349901 -0.794343
# 2  0.425372 -0.152015 -0.527282 -1.245129
# 3 -0.177185  0.108276 -0.130570 -1.713837
# 4  2.364708 -0.261616 -0.041494  0.941653
# 0 -0.209179 -0.326375  0.440166 -0.590773
# 1 -0.674814 -0.286429 -1.083910  0.730554
# 2 -2.049614 -0.767186 -2.532260 -0.988238
# 3 -0.799530  0.584514 -0.807622  0.101311
# 4 -0.095490 -0.078373  0.604457 -0.119861

# %% [markdown]
# If your `DataFrames` do not have an identical structure, but do share a common key, you can also perform a SQL-style join using the `.merge()` function:

# %%
left = pandas.DataFrame({'blah': ['foo', 'bar'], 
                         'lval': [1, 2]})
left
# Out:
#   blah  lval
# 0  foo     1
# 1  bar     2

# %%
right = pandas.DataFrame({'blah': ['foo', 'foo', 'bar'], 
                          'rval': [3, 4, 5]})
right
# Out:
#   blah  rval
# 0  foo     3
# 1  foo     4
# 2  bar     5

# %%
joined_data = pandas.merge(left, right, on = "blah")
joined_data
# Out:
#   blah  lval  rval
# 0  foo     1     3
# 1  foo     1     4
# 2  bar     2     5

# %% [markdown]
# Don't worry, `dfply` lets us do this using `join`s too:

# %%
left >> inner_join(right, by = "blah")
# Out:
#   blah  lval  rval
# 0  foo     1     3
# 1  foo     1     4
# 2  bar     2     5

# %% [markdown]
# ## Grouping
# Sometimes when working with multivariate data, it's helpful to be able to condense the data along a certain dimension in order to perform a calculation for efficiently. Let's start by creating a somewhat messy `DataFrame`:

# %%
foo_bar = pandas.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar','foo', 'bar', 'foo', 'foo'],
                            'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                            'C' : numpy.random.randn(8),
                            'D' : numpy.random.randn(8)})
foo_bar
# Out:
#      A      B         C         D
# 0  foo    one -1.238884 -0.309300
# 1  bar    one -0.368928 -0.908468
# 2  foo    two -1.661173 -2.226604
# 3  bar  three -0.115333 -0.343301
# 4  foo    two -0.725903 -0.471137
# 5  bar    two -0.046243 -0.192956
# 6  foo    one  1.995964 -1.287997
# 7  foo  three -1.216880 -0.369483

# %% [markdown]
# Now let's group by column `A`, and `sum()` along the other columns:

# %%
foo_bar.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.530504 -1.444725
# foo -2.846876 -4.664520

# %% [markdown]
# Note that column `B` was dropped, because the summation operator doesn't make sense on strings. However, if we wanted to retain that information, we could perform the same operation using a hierarchical index:

# %%
grouped = foo_bar.groupby(['A','B']).sum()
grouped
# Out:
#                   C         D
# A   B
# bar one   -0.368928 -0.908468
#     three -0.115333 -0.343301
#     two   -0.046243 -0.192956
# foo one    0.757080 -1.597296
#     three -1.216880 -0.369483
#     two   -2.387076 -2.697741

# %% [markdown]
# The `stack()` function can be used to "compress” a level in the `DataFrame`’s columns:

# %%
stacked = grouped.stack()
stacked
# Out:
# A    B
# bar  one    C   -0.368928
#             D   -0.908468
#      three  C   -0.115333
#             D   -0.343301
#      two    C   -0.046243
#             D   -0.192956
# foo  one    C    0.757080
#             D   -1.597296
#      three  C   -1.216880
#             D   -0.369483
#      two    C   -2.387076
#             D   -2.697741
# dtype: float64

# %% [markdown]
# To uncompress the last column of a stacked `DataFrame`, you can call `.unstack()`:

# %%
stacked.unstack()
# Out:
#                   C         D
# A   B
# bar one   -0.368928 -0.908468
#     three -0.115333 -0.343301
#     two   -0.046243 -0.192956
# foo one    0.757080 -1.597296
#     three -1.216880 -0.369483
#     two   -2.387076 -2.697741

# %% [markdown]
# ## Time Series
# `pandas` has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (for example, converting secondly data into minutely data). Firse, let's create an array of 150 `dateTime` objects at a frequency of 1 second:

# %%
rng = pandas.date_range('1/1/2021', 
                        periods = 350, 
                        freq = 'S')
rng
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 00:00:01',
#                '2021-01-01 00:00:02', '2021-01-01 00:00:03',
#                '2021-01-01 00:00:04', '2021-01-01 00:00:05',
#                '2021-01-01 00:00:06', '2021-01-01 00:00:07',
#                '2021-01-01 00:00:08', '2021-01-01 00:00:09',
#                ...
#                '2021-01-01 00:05:40', '2021-01-01 00:05:41',
#                '2021-01-01 00:05:42', '2021-01-01 00:05:43',
#                '2021-01-01 00:05:44', '2021-01-01 00:05:45',
#                '2021-01-01 00:05:46', '2021-01-01 00:05:47',
#                '2021-01-01 00:05:48', '2021-01-01 00:05:49'],
#               dtype='datetime64[ns]', length=350, freq='S')

# %% [markdown]
# Now we'll use that to greate a time series, assigning a random integer to each element of the range:

# %%
time_series = pandas.Series(numpy.random.randint(0, 500, len(rng)), 
                            index = rng)
time_series.head()
# Out:
# 2021-01-01 00:00:00     24
# 2021-01-01 00:00:01    275
# 2021-01-01 00:00:02     89
# 2021-01-01 00:00:03    126
# 2021-01-01 00:00:04    466
# Freq: S, dtype: int64

# %% [markdown]
# Next, we'll resample the data by binning the one-second raw values into minutes (and summing the associated values):

# %%
time_series.resample('1Min').sum()
# Out:
# 2021-01-01 00:00:00    13330
# 2021-01-01 00:01:00    15599
# 2021-01-01 00:02:00    17343
# 2021-01-01 00:03:00    16661
# 2021-01-01 00:04:00    16774
# 2021-01-01 00:05:00    11785
# Freq: T, dtype: int64

# %% [markdown]
# We also have support for time zone conversion. For example, if we assume the original `time_series` was in UTC:

# %%
ts_utc = time_series.tz_localize('UTC')
ts_utc.head()
# Out:
# 2021-01-01 00:00:00+00:00     24
# 2021-01-01 00:00:01+00:00    275
# 2021-01-01 00:00:02+00:00     89
# 2021-01-01 00:00:03+00:00    126
# 2021-01-01 00:00:04+00:00    466
# Freq: S, dtype: int64

# %% [markdown]
# We can easily convert it to Eastern time:

# %%
ts_utc.tz_convert('US/Eastern').head()
# Out:
# 2020-12-31 19:00:00-05:00     24
# 2020-12-31 19:00:01-05:00    275
# 2020-12-31 19:00:02-05:00     89
# 2020-12-31 19:00:03-05:00    126
# 2020-12-31 19:00:04-05:00    466
# Freq: S, dtype: int64

# %% [markdown]
# ## Reading/Writing to files
# Writing to a file works just like we'd expect:

# %%
ts_utc.to_csv("foo.csv")

# %% [markdown]
# As does reading:

# %%
new_frame = pandas.read_csv("foo.csv")
new_frame.head()
# Out:
#                   Unnamed: 0    0
# 0  2021-01-01 00:00:00+00:00   24
# 1  2021-01-01 00:00:01+00:00  275
# 2  2021-01-01 00:00:02+00:00   89
# 3  2021-01-01 00:00:03+00:00  126
# 4  2021-01-01 00:00:04+00:00  466

# %% [markdown]
# We can also read/write to `.xlsx` format, if for some reason we want to work in Excel:

# %%
ts_utc.to_excel("foo.xlsx", sheet_name = "Sample 1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-59-8f0510dabb46> in <module>
# ----> 1 ts_utc.to_excel("foo.xlsx", sheet_name = "Sample 1")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2030             startcol=startcol,
#    2031             freeze_panes=freeze_panes,
# -> 2032             engine=engine,
#    2033         )
#    2034
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# --> 730             writer = ExcelWriter(stringify_path(writer), engine=engine)
#     731             need_save = True
#     732
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, mode, **engine_kwargs)
#      16     def __init__(self, path, engine=None, mode="w", **engine_kwargs):
#      17         # Use the openpyxl module as the Excel writer.
# ---> 18         from openpyxl.workbook import Workbook
#      19
#      20         super().__init__(path, mode=mode, **engine_kwargs)
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [markdown]
# But what if the data is a little... messy? Something like this:

# %%
broken_df = pandas.read_csv('bikes.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-60-5cbf25f4669a> in <module>
# ----> 1 broken_df = pandas.read_csv('bikes.csv')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 15: invalid continuation byte

# %% [markdown]
# No problem! The `read_csv()` function has lots of tools to help wrangle this mess. Here we'll
#
#     - change the column separator to a ;
#     - Set the encoding to `latin1` (the default is `utf8`)
#     - Parse the dates in the `Date` column
#     - Tell it that our dates have the day first instead of the month first

# %%
fixed_df = pandas.read_csv('bikes.csv', 
                           sep = ';', 
                           encoding = 'latin1', 
                           parse_dates = ['Date'], 
                           dayfirst = True)
fixed_df.head()
# Out:
#         Date  Berri 1  Brébeuf (données non disponibles)  \
# 0 2012-01-01       35                                NaN
# 1 2012-01-02       83                                NaN
# 2 2012-01-03      135                                NaN
# 3 2012-01-04      144                                NaN
# 4 2012-01-05      197                                NaN
#
#    Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
# 3                      1            116            318      111             8
# 4                      2            124            330       97            13
#
#    Rachel1  St-Urbain (données non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# 2       58                                  NaN
# 3       61                                  NaN
# 4       95                                  NaN

# %% [markdown]
# ## Scraping Data
# Many of you will probably be interested in scraping data from the web for your projects. For example, what if we were interested in working with some data on municipalities in the state of Massachusetts? Well, we can get that from https://en.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts
#
# First, we'll import two useful libraries: `requests` (to query a URL) and `BeautifulSoup` (to parse the web page):

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Now let's request the page:

# %%
result = requests.get("https://en.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts")
result
# Out:
# <Response [200]>

# %% [markdown]
# The response code `[200]` indicates that the request was successful. Now let's use `BeautifulSoup` to parse the web page into something semi-readable:

# %%
page = result.content
soup = BeautifulSoup(page)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of municipalities in Massachusetts - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YDZ1e5@mDsw7HA7MW2194AAAAAg","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_municipalities_in_Massachusetts","wgTitle":"List of municipalities in Massachusetts","wgCurRevisionId":1008110155,"wgRevisionId":1008110155,"wgArticleId":8673763,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","All articles with dead external links","Articles with dead external links from April 2020","Articles with short description","Short description is different from Wikidata",
# "Wikipedia articles in need of updating from October 2020","All Wikipedia articles in need of updating","All articles with unsourced statements","Articles with unsourced statements from August 2018","Commons category link is on Wikidata","Cities in Massachusetts","Lists of cities in the United States by state","Lists of towns in the United States","Massachusetts geography-related lists","Towns in Massachusetts","Lists of places in Massachusetts"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_municipalities_in_Massachusetts","wgRelevantArticleId":8673763,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgPopupsConflictsWithRefTooltipsGadget":!0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":
# "en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q1761265"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","mediawiki.page.gallery.styles":"ready","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["mediawiki.page.gallery","ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible",
# "mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.page.gallery.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.36.0-wmf.31" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/MA_cities_towns.svg/1200px-MA_cities_towns.svg.png" property="og:image"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/List_of_municipalities_in_Massachusetts" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_municipalities_in_Massachusetts rootpage-List_of_municipalities_in_Massachusetts skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading">
#     List of municipalities in Massachusetts
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Wikipedia list article
#       </div>
#       <table class="box-Update plainlinks metadata ambox ambox-content ambox-Update" role="presentation">
#        <tbody>
#         <tr>
#          <td class="mbox-image">
#           <div style="width:52px">
#            <img alt="Ambox current red Asia Australia.svg" data-file-height="290" data-file-width="360" decoding="async" height="34" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Ambox_current_red_Asia_Australia.svg/42px-Ambox_current_red_Asia_Australia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Ambox_current_red_Asia_Australia.svg/63px-Ambox_current_red_Asia_Australia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Ambox_current_red_Asia_Australia.svg/84px-Ambox_current_red_Asia_Australia.svg.png 2x" width="42"/>
#           </div>
#          </td>
#          <td class="mbox-text">
#           <div class="mbox-text-span">
#            This article needs to be
#            <b>
#             updated
#            </b>
#            .
#            <span class="hide-when-compact">
#             Please update this article to reflect recent events or newly available information.
#            </span>
#            <small class="date-container">
#             <i>
#              (
#              <span class="date">
#               October 2020
#              </span>
#              )
#             </i>
#            </small>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <table class="infobox vevent" style="width:22em;float: right; width: 250px; font-size: 90%; text-align: left; border-spacing: 3px;">
#        <tbody>
#         <tr>
#          <th class="summary" colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size: 130%; background-color: #F0F0F0; vertical-align: middle">
#           Municipalities in Massachusetts
#          </th>
#         </tr>
#         <tr>
#          <td colspan="2" style="text-align:center;font-weight: bold;">
#           <span style="font-weight: normal;">
#            Also known as:
#           </span>
#           <br/>
#           City
#           <br/>
#           Town
#          </td>
#         </tr>
#         <tr>
#          <td colspan="2" style="text-align:center">
#           <a class="image" href="/wiki/File:MA_cities_towns.svg">
#            <img alt="MA cities towns.svg" data-file-height="1300" data-file-width="2100" decoding="async" height="173" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6e/MA_cities_towns.svg/280px-MA_cities_towns.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6e/MA_cities_towns.svg/420px-MA_cities_towns.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6e/MA_cities_towns.svg/560px-MA_cities_towns.svg.png 2x" width="280"/>
#           </a>
#           <a class="image" href="/wiki/File:Massachusetts_in_United_States.svg">
#            <img alt="Massachusetts in United States.svg" data-file-height="731" data-file-width="1181" decoding="async" height="173" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Massachusetts_in_United_States.svg/280px-Massachusetts_in_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Massachusetts_in_United_States.svg/420px-Massachusetts_in_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f5/Massachusetts_in_United_States.svg/560px-Massachusetts_in_United_States.svg.png 2x" width="280"/>
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Category
#          </th>
#          <td style="line-height:1.3em;">
#           Municipality
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Location
#          </th>
#          <td style="line-height:1.3em;">
#           <a href="/wiki/Massachusetts" title="Massachusetts">
#            Massachusetts
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Found in
#          </th>
#          <td style="line-height:1.3em;">
#           <a href="/wiki/County" title="County">
#            County
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Created
#          </th>
#          <td style="line-height:1.3em;">
#           1620
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <p>
#        <br/>
#        <a href="/wiki/Massachusetts" title="Massachusetts">
#         Massachusetts
#        </a>
#        is a
#        <a href="/wiki/U.S._state" title="U.S. state">
#         state
#        </a>
#        located in the
#        <a href="/wiki/Northeastern_United_States" title="Northeastern United States">
#         Northeastern United States
#        </a>
#        .
#        <a href="/wiki/Municipality" title="Municipality">
#         Municipalities
#        </a>
#        in the state are classified as either towns or cities, distinguished by their form of government under state law. Towns have an
#        <a class="mw-redirect" href="/wiki/Open_town_meeting" title="Open town meeting">
#         open town meeting
#        </a>
#        or
#        <a href="/wiki/Representative_town_meeting" title="Representative town meeting">
#         representative town meeting
#        </a>
#        form of government; cities, on the other hand, use a
#        <a class="mw-redirect" href="/wiki/Mayor-council" title="Mayor-council">
#         mayor-council
#        </a>
#        or
#        <a class="mw-redirect" href="/wiki/Council-manager" title="Council-manager">
#         council-manager
#        </a>
#        form. Based on the form of government, there are 294 towns and 57 cities in Massachusetts. Some municipalities, however, still refer to themselves as "towns" even though they have a city form of government.
#       </p>
#       <p>
#        The
#        <a href="/wiki/United_States_Census_Bureau" title="United States Census Bureau">
#         Census Bureau
#        </a>
#        classifies towns in Massachusetts as a type of "
#        <a href="/wiki/Minor_civil_division" title="Minor civil division">
#         minor civil division
#        </a>
#        " and cities as a type of "
#        <a href="/wiki/Place_(United_States_Census_Bureau)" title="Place (United States Census Bureau)">
#         populated place
#        </a>
#        ". However, from the perspective of Massachusetts law, politics, and geography, cities and towns are the same type of municipal unit, differing only in their form of government.
#       </p>
#       <p>
#        There is no
#        <a class="mw-redirect" href="/wiki/Unincorporated_land" title="Unincorporated land">
#         unincorporated land
#        </a>
#        in Massachusetts; the land area of the state is completely divided up among the 351 municipalities.
#       </p>
#       <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="en">
#         <h2 id="mw-toc-heading">
#          Contents
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#List_of_municipalities">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            List of municipalities
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-2">
#          <a href="#List_of_cities_by_official_name">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            List of cities by official name
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-3">
#          <a href="#Geography_of_towns_at_formation">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            Geography of towns at formation
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-4">
#          <a href="#Former_municipalities">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            Former municipalities
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-5">
#            <a href="#Annexations">
#             <span class="tocnumber">
#              4.1
#             </span>
#             <span class="toctext">
#              Annexations
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-6">
#            <a href="#Disincorporations">
#             <span class="tocnumber">
#              4.2
#             </span>
#             <span class="toctext">
#              Disincorporations
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-7">
#            <a href="#Cessions">
#             <span class="tocnumber">
#              4.3
#             </span>
#             <span class="toctext">
#              Cessions
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-8">
#          <a href="#Archaic_names">
#           <span class="tocnumber">
#            5
#           </span>
#           <span class="toctext">
#            Archaic names
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-9">
#          <a href="#See_also">
#           <span class="tocnumber">
#            6
#           </span>
#           <span class="toctext">
#            See also
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-10">
#          <a href="#Notes">
#           <span class="tocnumber">
#            7
#           </span>
#           <span class="toctext">
#            Notes
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-11">
#          <a href="#References">
#           <span class="tocnumber">
#            8
#           </span>
#           <span class="toctext">
#            References
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-12">
#          <a href="#External_links">
#           <span class="tocnumber">
#            9
#           </span>
#           <span class="toctext">
#            External links
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <h2>
#        <span class="mw-headline" id="List_of_municipalities">
#         List of municipalities
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;action=edit&amp;section=1" title="Edit section: List of municipalities">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <ul class="gallery mw-gallery-packed">
#        <li class="gallerycaption">
#         Largest municipalities in Massachusetts by population
#        </li>
#        <li class="gallerybox" style="width: 167.33333333333px">
#         <div style="width: 167.33333333333px">
#          <div class="thumb" style="width: 165.33333333333px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:DowntownBoston.jpg">
#             <img alt="Skyline of Boston" data-file-height="1892" data-file-width="2405" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/DowntownBoston.jpg/248px-DowntownBoston.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/DowntownBoston.jpg/373px-DowntownBoston.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/63/DowntownBoston.jpg/496px-DowntownBoston.jpg 2x" width="166"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Skyline of
#            <a href="/wiki/Boston" title="Boston">
#             Boston
#            </a>
#            , largest municipality by population in
#            <a href="/wiki/Massachusetts" title="Massachusetts">
#             Massachusetts
#            </a>
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 263.33333333333px">
#         <div style="width: 263.33333333333px">
#          <div class="thumb" style="width: 261.33333333333px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:Downtown_Worcester,_Massachusetts.jpg">
#             <img alt="Downtown Worcester" data-file-height="1581" data-file-width="3177" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Downtown_Worcester%2C_Massachusetts.jpg/392px-Downtown_Worcester%2C_Massachusetts.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Downtown_Worcester%2C_Massachusetts.jpg/589px-Downtown_Worcester%2C_Massachusetts.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/90/Downtown_Worcester%2C_Massachusetts.jpg/784px-Downtown_Worcester%2C_Massachusetts.jpg 2x" width="262"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Downtown
#            <a href="/wiki/Worcester,_Massachusetts" title="Worcester, Massachusetts">
#             Worcester
#            </a>
#            , Massachusetts's second largest municipality by population
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 542px">
#         <div style="width: 542px">
#          <div class="thumb" style="width: 540px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:Springfield_Skyline,_MA.jpg">
#             <img alt="" data-file-height="894" data-file-width="3711" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Springfield_Skyline%2C_MA.jpg/810px-Springfield_Skyline%2C_MA.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Springfield_Skyline%2C_MA.jpg/1217px-Springfield_Skyline%2C_MA.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Springfield_Skyline%2C_MA.jpg/1619px-Springfield_Skyline%2C_MA.jpg 2x" width="540"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Skyline of
#            <a href="/wiki/Springfield,_Massachusetts" title="Springfield, Massachusetts">
#             Springfield
#            </a>
#            , third largest municipality by population in Massachusetts
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 197.33333333333px">
#         <div style="width: 197.33333333333px">
#          <div class="thumb" style="width: 195.33333333333px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:Lowell_skyline.jpg">
#             <img alt="" data-file-height="333" data-file-width="500" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Lowell_skyline.jpg/293px-Lowell_skyline.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Lowell_skyline.jpg/440px-Lowell_skyline.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/2/2a/Lowell_skyline.jpg 2x" width="196"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Skyline of
#            <a href="/wiki/Lowell,_Massachusetts" title="Lowell, Massachusetts">
#             Lowell
#            </a>
#            , fourth largest municipality by population in Massachusetts
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 197.33333333333px">
#         <div style="width: 197.33333333333px">
#          <div class="thumb" style="width: 195.33333333333px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:Cambridge_Skyline.jpg">
#             <img alt="" data-file-height="532" data-file-width="800" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Cambridge_Skyline.jpg/293px-Cambridge_Skyline.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Cambridge_Skyline.jpg/441px-Cambridge_Skyline.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Cambridge_Skyline.jpg/587px-Cambridge_Skyline.jpg 2x" width="196"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Skyline of
#            <a href="/wiki/Cambridge,_Massachusetts" title="Cambridge, Massachusetts">
#             Cambridge
#            </a>
#            , Massachusetts's fifth largest municipality by population
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 212px">
#         <div style="width: 212px">
#          <div class="thumb" style="width: 210px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:NewBedford21June07HarborViewInland.jpg">
#             <img alt="" data-file-height="1738" data-file-width="2806" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bd/NewBedford21June07HarborViewInland.jpg/315px-NewBedford21June07HarborViewInland.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bd/NewBedford21June07HarborViewInland.jpg/473px-NewBedford21June07HarborViewInland.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bd/NewBedford21June07HarborViewInland.jpg/630px-NewBedford21June07HarborViewInland.jpg 2x" width="210"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Downtown
#            <a href="/wiki/New_Bedford,_Massachusetts" title="New Bedford, Massachusetts">
#             New Bedford
#            </a>
#            , the sixth largest municipality by population in Massachusetts
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 102px">
#         <div style="width: 102px">
#          <div class="thumb" style="width: 100px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:BrocktonCityHall.jpg">
#             <img alt="" data-file-height="3657" data-file-width="2821" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/BrocktonCityHall.jpg/150px-BrocktonCityHall.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/BrocktonCityHall.jpg/226px-BrocktonCityHall.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/85/BrocktonCityHall.jpg/301px-BrocktonCityHall.jpg 2x" width="100"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            City Hall in
#            <a href="/wiki/Brockton,_Massachusetts" title="Brockton, Massachusetts">
#             Brockton
#            </a>
#            , Massachusetts seventh largest municipality by population
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 175.33333333333px">
#         <div style="width: 175.33333333333px">
#          <div class="thumb" style="width: 173.33333333333px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:Quincycenter.jpg">
#             <img alt="" data-file-height="1944" data-file-width="2592" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/97/Quincycenter.jpg/260px-Quincycenter.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/97/Quincycenter.jpg/391px-Quincycenter.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/97/Quincycenter.jpg/520px-Quincycenter.jpg 2x" width="174"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Downtown
#            <a href="/wiki/Quincy,_Massachusetts" title="Quincy, Massachusetts">
#             Quincy
#            </a>
#            , eighth largest municipality by population in Massachusetts
#           </p>
#          </div>
#         </div>
#        </li>
#        <li class="gallerybox" style="width: 586px">
#         <div style="width: 586px">
#          <div class="thumb" style="width: 584px;">
#           <div style="margin:0px auto;">
#            <a class="image" href="/wiki/File:Panorama_of_Lynn,_Massachusetts,_from_High_Rock_Tower.jpg">
#             <img alt="" data-file-height="2487" data-file-width="11170" decoding="async" height="130" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Panorama_of_Lynn%2C_Massachusetts%2C_from_High_Rock_Tower.jpg/876px-Panorama_of_Lynn%2C_Massachusetts%2C_from_High_Rock_Tower.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Panorama_of_Lynn%2C_Massachusetts%2C_from_High_Rock_Tower.jpg/1316px-Panorama_of_Lynn%2C_Massachusetts%2C_from_High_Rock_Tower.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Panorama_of_Lynn%2C_Massachusetts%2C_from_High_Rock_Tower.jpg/1752px-Panorama_of_Lynn%2C_Massachusetts%2C_from_High_Rock_Tower.jpg 2x" width="584"/>
#            </a>
#           </div>
#          </div>
#          <div class="gallerytext">
#           <p>
#            Skyline of
#            <a href="/wiki/Lynn,_Massachusetts" title="Lynn, Massachusetts">
#             Lynn
#            </a>
#            , ninth largest municipality by population in Massachusetts
#           </p>
#          </div>
#         </div>
#        </li>
#       </ul>
#       <table class="wikitable sortable">
#        <tbody>
#         <tr valign="bottom">
#          <th>
#           Municipality
#          </th>
#          <th>
#           Type
#           <sup class="reference" id="cite_ref-MMA_1-0">
#            <a href="#cite_note-MMA-1">
#             [1]
#            </a>
#           </sup>
#          </th>
#          <th>
#           County
#           <sup class="reference" id="cite_ref-census_2-0">
#            <a href="#cite_note-census-2">
#             [2]
#            </a>
#           </sup>
#          </th>
#          <th>
#           Form of government
#           <sup class="reference" id="cite_ref-MMA_1-1">
#            <a href="#cite_note-MMA-1">
#             [1]
#            </a>
#           </sup>
#          </th>
#          <th>
#           Population
#           <br/>
#           (2010)
#           <sup class="reference" id="cite_ref-census_2-1">
#            <a href="#cite_note-census-2">
#             [2]
#            </a>
#           </sup>
#          </th>
#          <th>
#           Total area
#           <br/>
#           (sq mi)
#          </th>
#          <th>
#           Year
#           <br/>
#           established
#           <sup class="reference" id="cite_ref-CIS_3-0">
#            <a href="#cite_note-CIS-3">
#             [3]
#            </a>
#           </sup>
#          </th>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Abington,_Massachusetts" title="Abington, Massachusetts">
#            Abington
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Plymouth
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           15,985
#          </td>
#          <td>
#           9.9
#          </td>
#          <td align="center">
#           1712
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Acton,_Massachusetts" title="Acton, Massachusetts">
#            Acton
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           21,924
#          </td>
#          <td>
#           20.3
#          </td>
#          <td align="center">
#           1735
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Acushnet,_Massachusetts" title="Acushnet, Massachusetts">
#            Acushnet
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Bristol
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           10,303
#          </td>
#          <td>
#           19.0
#          </td>
#          <td align="center">
#           1860
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Adams,_Massachusetts" title="Adams, Massachusetts">
#            Adams
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Berkshire
#          </td>
#          <td>
#           Representative town meeting
#          </td>
#          <td align="right">
#           8,485
#          </td>
#          <td>
#           23.0
#          </td>
#          <td align="center">
#           1778
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Agawam,_Massachusetts" title="Agawam, Massachusetts">
#            Agawam
#           </a>
#          </td>
#          <td>
#           City
#           <sup class="reference" id="cite_ref-TC_4-0">
#            <a href="#cite_note-TC-4">
#             [4]
#            </a>
#           </sup>
#          </td>
#          <td>
#           Hampden
#          </td>
#          <td>
#           Mayor-council
#          </td>
#          <td align="right">
#           28,438
#          </td>
#          <td>
#           24.3
#          </td>
#          <td align="center">
#           1855
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Alford,_Massachusetts" title="Alford, Massachusetts">
#            Alford
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Berkshire
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           494
#          </td>
#          <td>
#           11.5
#          </td>
#          <td align="center">
#           1773
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Amesbury,_Massachusetts" title="Amesbury, Massachusetts">
#            Amesbury
#           </a>
#          </td>
#          <td>
#           City
#          </td>
#          <td>
#           Essex
#          </td>
#          <td>
#           Mayor-council
#          </td>
#          <td align="right">
#           16,283
#          </td>
#          <td>
#           17.3
#          </td>
#          <td align="center">
#           1668
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Amherst,_Massachusetts" title="Amherst, Massachusetts">
#            Amherst
#           </a>
#          </td>
#          <td>
#           City
#           <sup class="reference" id="cite_ref-TC_4-1">
#            <a href="#cite_note-TC-4">
#             [4]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-5">
#            <a href="#cite_note-5">
#             [5]
#            </a>
#           </sup>
#          </td>
#          <td>
#           Hampshire
#          </td>
#          <td>
#           Council-manager
#          </td>
#          <td align="right">
#           37,819
#          </td>
#          <td>
#           27.7
#          </td>
#          <td align="center">
#           1775
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Andover,_Massachusetts" title="Andover, Massachusetts">
#            Andover
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Essex
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           33,201
#          </td>
#          <td>
#           32.1
#          </td>
#          <td align="center">
#           1646
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Aquinnah,_Massachusetts" title="Aquinnah, Massachusetts">
#            Aquinnah
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Dukes
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           311
#          </td>
#          <td>
#           40.8
#          </td>
#          <td align="center">
#           1870
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Arlington,_Massachusetts" title="Arlington, Massachusetts">
#            Arlington
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Representative town meeting
#          </td>
#          <td align="right">
#           42,844
#          </td>
#          <td>
#           5.5
#          </td>
#          <td align="center">
#           1807
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Ashburnham,_Massachusetts" title="Ashburnham, Massachusetts">
#            Ashburnham
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Worcester
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           6,081
#          </td>
#          <td>
#           41.0
#          </td>
#          <td align="center">
#           1765
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Ashby,_Massachusetts" title="Ashby, Massachusetts">
#            Ashby
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           3,074
#          </td>
#          <td>
#           24.2
#          </td>
#          <td align="center">
#           1767
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Ashfield,_Massachusetts" title="Ashfield, Massachusetts">
#            Ashfield
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Franklin
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           1,737
#          </td>
#          <td>
#           40.3
#          </td>
#          <td align="center">
#           1765
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Ashland,_Massachusetts" title="Ashland, Massachusetts">
#            Ashland
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           16,593
#          </td>
#          <td>
#           12.9
#          </td>
#          <td align="center">
#           1846
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Athol,_Massachusetts" title="Athol, Massachusetts">
#            Athol
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Worcester
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           11,584
#          </td>
#          <td>
#           33.4
#          </td>
#          <td align="center">
#           1762
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Attleboro,_Massachusetts" title="Attleboro, Massachusetts">
#            Attleboro
#           </a>
#          </td>
#          <td>
#           City
#          </td>
#          <td>
#           Bristol
#          </td>
#          <td>
#           Mayor-council
#          </td>
#          <td align="right">
#           43,593
#          </td>
#          <td>
#           27.8
#          </td>
#          <td align="center">
#           1694
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Auburn,_Massachusetts" title="Auburn, Massachusetts">
#            Auburn
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Worcester
#          </td>
#          <td>
#           Representative town meeting
#          </td>
#          <td align="right">
#           16,188
#          </td>
#          <td>
#           16.4
#          </td>
#          <td align="center">
#           1778
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Avon,_Massachusetts" title="Avon, Massachusetts">
#            Avon
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Norfolk
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           4,356
#          </td>
#          <td>
#           4.6
#          </td>
#          <td align="center">
#           1888
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Ayer,_Massachusetts" title="Ayer, Massachusetts">
#            Ayer
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           7,427
#          </td>
#          <td>
#           9.6
#          </td>
#          <td align="center">
#           1871
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Barnstable,_Massachusetts" title="Barnstable, Massachusetts">
#            Barnstable
#           </a>
#          </td>
#          <td>
#           City
#           <sup class="reference" id="cite_ref-TC_4-2">
#            <a href="#cite_note-TC-4">
#             [4]
#            </a>
#           </sup>
#          </td>
#          <td>
#           Barnstable
#          </td>
#          <td>
#           Council-manager
#          </td>
#          <td align="right">
#           45,193
#          </td>
#          <td>
#           76.5
#          </td>
#          <td align="center">
#           1639
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Barre,_Massachusetts" title="Barre, Massachusetts">
#            Barre
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Worcester
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           5,398
#          </td>
#          <td>
#           44.6
#          </td>
#          <td align="center">
#           1774
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Becket,_Massachusetts" title="Becket, Massachusetts">
#            Becket
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Berkshire
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           1,779
#          </td>
#          <td>
#           47.8
#          </td>
#          <td align="center">
#           1765
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Bedford,_Massachusetts" title="Bedford, Massachusetts">
#            Bedford
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           13,320
#          </td>
#          <td>
#           13.9
#          </td>
#          <td align="center">
#           1729
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Belchertown,_Massachusetts" title="Belchertown, Massachusetts">
#            Belchertown
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Hampshire
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           14,649
#          </td>
#          <td>
#           55.4
#          </td>
#          <td align="center">
#           1761
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Bellingham,_Massachusetts" title="Bellingham, Massachusetts">
#            Bellingham
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Norfolk
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           16,332
#          </td>
#          <td>
#           19.0
#          </td>
#          <td align="center">
#           1719
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Belmont,_Massachusetts" title="Belmont, Massachusetts">
#            Belmont
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Representative town meeting
#          </td>
#          <td align="right">
#           24,729
#          </td>
#          <td>
#           4.7
#          </td>
#          <td align="center">
#           1859
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Berkley,_Massachusetts" title="Berkley, Massachusetts">
#            Berkley
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Bristol
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           6,411
#          </td>
#          <td>
#           17.4
#          </td>
#          <td align="center">
#           1735
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Berlin,_Massachusetts" title="Berlin, Massachusetts">
#            Berlin
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Worcester
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           2,866
#          </td>
#          <td>
#           13.1
#          </td>
#          <td align="center">
#           1812
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Bernardston,_Massachusetts" title="Bernardston, Massachusetts">
#            Bernardston
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Franklin
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           2,129
#          </td>
#          <td>
#           23.4
#          </td>
#          <td align="center">
#           1762
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Beverly,_Massachusetts" title="Beverly, Massachusetts">
#            Beverly
#           </a>
#          </td>
#          <td>
#           City
#          </td>
#          <td>
#           Essex
#          </td>
#          <td>
#           Mayor-council
#          </td>
#          <td align="right">
#           39,502
#          </td>
#          <td>
#           22.6
#          </td>
#          <td align="center">
#           1668
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Billerica,_Massachusetts" title="Billerica, Massachusetts">
#            Billerica
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Middlesex
#          </td>
#          <td>
#           Representative town meeting
#          </td>
#          <td align="right">
#           40,243
#          </td>
#          <td>
#           26.4
#          </td>
#          <td align="center">
#           1655
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Blackstone,_Massachusetts" title="Blackstone, Massachusetts">
#            Blackstone
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Worcester
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           9,026
#          </td>
#          <td>
#           11.2
#          </td>
#          <td align="center">
#           1845
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Blandford,_Massachusetts" title="Blandford, Massachusetts">
#            Blandford
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Hampden
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           1,233
#          </td>
#          <td>
#           53.4
#          </td>
#          <td align="center">
#           1741
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Bolton,_Massachusetts" title="Bolton, Massachusetts">
#            Bolton
#           </a>
#          </td>
#          <td>
#           Town
#          </td>
#          <td>
#           Worcester
#          </td>
#          <td>
#           Open town meeting
#          </td>
#          <td align="right">
#           4,897
#          </td>
#          <td>
#           20.0
#          </td>
#          <td align="center">
#           1738
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/wiki/Boston" title="Boston">
#            Boston
#           </a>
#          </td>
#          <td>
#           City
#          </td>
#          <td>
#           Suffolk
#          </td>
#          <td>
#           Mayor-council
#          </td>
#          <td align="right">
#           617,660
#          </td>
#          <td>
#           89.6
#          </td>
#          <td align="center">
#           1630
#          </td>
#         </tr>
# ...
#          Help
#         </a>
#        </li>
#        <li id="n-introduction">
#         <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">
#          Learn to edit
#         </a>
#        </li>
#        <li id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">
#          Community portal
#         </a>
#        </li>
#        <li id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">
#          Recent changes
#         </a>
#        </li>
#        <li id="n-upload">
#         <a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">
#          Upload file
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
#      <h3 class="vector-menu-heading" id="p-tb-label">
#       <span>
#        Tools
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_municipalities_in_Massachusetts" title="List of all English Wikipedia pages containing links to this page [j]">
#          What links here
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_municipalities_in_Massachusetts" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          Related changes
#         </a>
#        </li>
#        <li id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          Upload file
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          Special pages
#         </a>
#        </li>
#        <li id="t-permalink">
#         <a href="/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;oldid=1008110155" title="Permanent link to this revision of this page">
#          Permanent link
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;action=info" title="More information about this page">
#          Page information
#         </a>
#        </li>
#        <li id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_municipalities_in_Massachusetts&amp;id=1008110155&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">
#          Cite this page
#         </a>
#        </li>
#        <li id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1761265" title="Structured data on this page hosted by Wikidata [g]">
#          Wikidata item
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#      <h3 class="vector-menu-heading" id="p-coll-print_export-label">
#       <span>
#        Print/export
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=List_of_municipalities_in_Massachusetts&amp;action=show-download-screen" title="Download this page as a PDF file">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-wikibase-otherprojects-label" class="mw-portlet mw-portlet-wikibase-otherprojects vector-menu vector-menu-portal portal" id="p-wikibase-otherprojects" role="navigation">
#      <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
#       <span>
#        In other projects
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="wb-otherproject-link wb-otherproject-commons">
#         <a href="https://commons.wikimedia.org/wiki/Category:Populated_places_in_Massachusetts" hreflang="en">
#          Wikimedia Commons
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#      <h3 class="vector-menu-heading" id="p-lang-label">
#       <span>
#        Languages
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="interlanguage-link interwiki-ar">
#         <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A8%D9%84%D8%AF%D9%8A%D8%A7%D8%AA_%D9%85%D8%A7%D8%B3%D8%A7%D8%AA%D8%B4%D9%88%D8%B3%D8%AA%D8%B3" hreflang="ar" lang="ar" title="قائمة بلديات ماساتشوستس – Arabic">
#          العربية
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bar">
#         <a class="interlanguage-link-target" href="https://bar.wikipedia.org/wiki/St%C3%A4dt_in_Massachusetts" hreflang="bar" lang="bar" title="Städt in Massachusetts – Bavarian">
#          Boarisch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-de">
#         <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_Massachusetts" hreflang="de" lang="de" title="Liste der Städte in Massachusetts – German">
#          Deutsch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-es">
#         <a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Anexo:Localidades_de_Massachusetts" hreflang="es" lang="es" title="Anexo:Localidades de Massachusetts – Spanish">
#          Español
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fa">
#         <a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D8%B4%D9%87%D8%B1%D9%87%D8%A7%DB%8C_%D9%85%D8%A7%D8%B3%D8%A7%DA%86%D9%88%D8%B3%D8%AA" hreflang="fa" lang="fa" title="فهرست شهرهای ماساچوست – Persian">
#          فارسی
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fr">
#         <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Liste_des_municipalit%C3%A9s_du_Massachusetts" hreflang="fr" lang="fr" title="Liste des municipalités du Massachusetts – French">
#          Français
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-it">
#         <a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Citt%C3%A0_del_Massachusetts" hreflang="it" lang="it" title="Città del Massachusetts – Italian">
#          Italiano
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sw">
#         <a class="interlanguage-link-target" href="https://sw.wikipedia.org/wiki/Orodha_ya_miji_ya_Massachusetts" hreflang="sw" lang="sw" title="Orodha ya miji ya Massachusetts – Swahili">
#          Kiswahili
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-no">
#         <a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/Liste_over_byer_i_Massachusetts" hreflang="nb" lang="nb" title="Liste over byer i Massachusetts – Norwegian Bokmål">
#          Norsk bokmål
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pt">
#         <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Lista_de_cidades_de_Massachusetts" hreflang="pt" lang="pt" title="Lista de cidades de Massachusetts – Portuguese">
#          Português
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ro">
#         <a class="interlanguage-link-target" href="https://ro.wikipedia.org/wiki/List%C4%83_de_ora%C8%99e_din_statul_Massachusetts" hreflang="ro" lang="ro" title="Listă de orașe din statul Massachusetts – Romanian">
#          Română
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ru">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%B3%D0%BE%D1%80%D0%BE%D0%B4%D0%BE%D0%B2_%D0%9C%D0%B0%D1%81%D1%81%D0%B0%D1%87%D1%83%D1%81%D0%B5%D1%82%D1%81%D0%B0_%D0%BF%D0%BE_%D1%87%D0%B8%D1%81%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE%D1%81%D1%82%D0%B8_%D0%BD%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F" hreflang="ru" lang="ru" title="Список городов Массачусетса по численности населения – Russian">
#          Русский
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-simple">
#         <a class="interlanguage-link-target" href="https://simple.wikipedia.org/wiki/List_of_settlements_in_Massachusetts" hreflang="en-simple" lang="en-simple" title="List of settlements in Massachusetts – Simple English">
#          Simple English
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tl">
#         <a class="interlanguage-link-target" href="https://tl.wikipedia.org/wiki/Talaan_ng_mga_lungsod_sa_Massachusetts" hreflang="tl" lang="tl" title="Talaan ng mga lungsod sa Massachusetts – Tagalog">
#          Tagalog
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tr">
#         <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/Massachusetts%27deki_%C5%9Fehirler_listesi" hreflang="tr" lang="tr" title="Massachusetts'deki şehirler listesi – Turkish">
#          Türkçe
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1761265#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 21 February 2021, at 16:44
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_municipalities_in_Massachusetts&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.927","walltime":"1.140","ppvisitednodes":{"value":2611,"limit":1000000},"postexpandincludesize":{"value":79988,"limit":2097152},"templateargumentsize":{"value":8376,"limit":2097152},"expansiondepth":{"value":17,"limit":40},"expensivefunctioncount":{"value":3,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":40312,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  686.335      1 -total"," 34.72%  238.317      2 Template:Reflist"," 26.21%  179.916      8 Template:Cite_web"," 11.56%   79.312      1 Template:Short_description"," 11.41%   78.328      1 Template:Infobox_subdivision_type"," 10.67%   73.225      1 Template:Infobox","  9.53%   65.388      8 Template:Main_other","  8.87%   60.867      1 Template:Massachusetts","  8.80%   60.380      1 Template:Update","  8.42%   57.788      2 Template:Navbox"]},"scribunto":{"limitreport-timeusage":{"value":"0.276","limit":"10.000"},"limitreport-memusage":{"value":5525880,"limit":52428800}},"cachereport":{"origin":"mw1335","timestamp":"20210221224711","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"List of municipalities in Massachusetts","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_municipalities_in_Massachusetts","sameAs":"http:\/\/www.wikidata.org\/entity\/Q1761265","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q1761265","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2006-12-30T15:04:30Z","dateModified":"2021-02-21T16:44:30Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/6\/6e\/MA_cities_towns.svg","headline":"Wikimedia list article"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":314,"wgHostname":"mw1327"});});
#   </script>
#  </body>
# </html>

# %% [markdown]
# Notice that there's a lot of code in there that isn't related to the data we're trying to get. If we inspect the page source of the table we're interested in, we see that it's a `<table>` elemnt with `class = wikitable sortable`. Let's ask `BeautifulSoup` to give us just that piece of the page:

# %%
table = soup.find("table", { "class" : "wikitable sortable" })
print(table.prettify())
# Out:
# <table class="wikitable sortable">
#  <tbody>
#   <tr valign="bottom">
#    <th>
#     Municipality
#    </th>
#    <th>
#     Type
#     <sup class="reference" id="cite_ref-MMA_1-0">
#      <a href="#cite_note-MMA-1">
#       [1]
#      </a>
#     </sup>
#    </th>
#    <th>
#     County
#     <sup class="reference" id="cite_ref-census_2-0">
#      <a href="#cite_note-census-2">
#       [2]
#      </a>
#     </sup>
#    </th>
#    <th>
#     Form of government
#     <sup class="reference" id="cite_ref-MMA_1-1">
#      <a href="#cite_note-MMA-1">
#       [1]
#      </a>
#     </sup>
#    </th>
#    <th>
#     Population
#     <br/>
#     (2010)
#     <sup class="reference" id="cite_ref-census_2-1">
#      <a href="#cite_note-census-2">
#       [2]
#      </a>
#     </sup>
#    </th>
#    <th>
#     Total area
#     <br/>
#     (sq mi)
#    </th>
#    <th>
#     Year
#     <br/>
#     established
#     <sup class="reference" id="cite_ref-CIS_3-0">
#      <a href="#cite_note-CIS-3">
#       [3]
#      </a>
#     </sup>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Abington,_Massachusetts" title="Abington, Massachusetts">
#      Abington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     15,985
#    </td>
#    <td>
#     9.9
#    </td>
#    <td align="center">
#     1712
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Acton,_Massachusetts" title="Acton, Massachusetts">
#      Acton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     21,924
#    </td>
#    <td>
#     20.3
#    </td>
#    <td align="center">
#     1735
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Acushnet,_Massachusetts" title="Acushnet, Massachusetts">
#      Acushnet
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     10,303
#    </td>
#    <td>
#     19.0
#    </td>
#    <td align="center">
#     1860
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Adams,_Massachusetts" title="Adams, Massachusetts">
#      Adams
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     8,485
#    </td>
#    <td>
#     23.0
#    </td>
#    <td align="center">
#     1778
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Agawam,_Massachusetts" title="Agawam, Massachusetts">
#      Agawam
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-0">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     28,438
#    </td>
#    <td>
#     24.3
#    </td>
#    <td align="center">
#     1855
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Alford,_Massachusetts" title="Alford, Massachusetts">
#      Alford
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     494
#    </td>
#    <td>
#     11.5
#    </td>
#    <td align="center">
#     1773
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Amesbury,_Massachusetts" title="Amesbury, Massachusetts">
#      Amesbury
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     16,283
#    </td>
#    <td>
#     17.3
#    </td>
#    <td align="center">
#     1668
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Amherst,_Massachusetts" title="Amherst, Massachusetts">
#      Amherst
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-1">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#     <sup class="reference" id="cite_ref-5">
#      <a href="#cite_note-5">
#       [5]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Council-manager
#    </td>
#    <td align="right">
#     37,819
#    </td>
#    <td>
#     27.7
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Andover,_Massachusetts" title="Andover, Massachusetts">
#      Andover
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     33,201
#    </td>
#    <td>
#     32.1
#    </td>
#    <td align="center">
#     1646
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Aquinnah,_Massachusetts" title="Aquinnah, Massachusetts">
#      Aquinnah
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Dukes
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     311
#    </td>
#    <td>
#     40.8
#    </td>
#    <td align="center">
#     1870
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Arlington,_Massachusetts" title="Arlington, Massachusetts">
#      Arlington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     42,844
#    </td>
#    <td>
#     5.5
#    </td>
#    <td align="center">
#     1807
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Ashburnham,_Massachusetts" title="Ashburnham, Massachusetts">
#      Ashburnham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,081
#    </td>
#    <td>
#     41.0
#    </td>
#    <td align="center">
#     1765
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Ashby,_Massachusetts" title="Ashby, Massachusetts">
#      Ashby
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,074
#    </td>
#    <td>
#     24.2
#    </td>
#    <td align="center">
#     1767
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Ashfield,_Massachusetts" title="Ashfield, Massachusetts">
#      Ashfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,737
#    </td>
#    <td>
#     40.3
#    </td>
#    <td align="center">
#     1765
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Ashland,_Massachusetts" title="Ashland, Massachusetts">
#      Ashland
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     16,593
#    </td>
#    <td>
#     12.9
#    </td>
#    <td align="center">
#     1846
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Athol,_Massachusetts" title="Athol, Massachusetts">
#      Athol
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     11,584
#    </td>
#    <td>
#     33.4
#    </td>
#    <td align="center">
#     1762
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Attleboro,_Massachusetts" title="Attleboro, Massachusetts">
#      Attleboro
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     43,593
#    </td>
#    <td>
#     27.8
#    </td>
#    <td align="center">
#     1694
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Auburn,_Massachusetts" title="Auburn, Massachusetts">
#      Auburn
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     16,188
#    </td>
#    <td>
#     16.4
#    </td>
#    <td align="center">
#     1778
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Avon,_Massachusetts" title="Avon, Massachusetts">
#      Avon
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,356
#    </td>
#    <td>
#     4.6
#    </td>
#    <td align="center">
#     1888
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Ayer,_Massachusetts" title="Ayer, Massachusetts">
#      Ayer
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,427
#    </td>
#    <td>
#     9.6
#    </td>
#    <td align="center">
#     1871
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Barnstable,_Massachusetts" title="Barnstable, Massachusetts">
#      Barnstable
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-2">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Council-manager
#    </td>
#    <td align="right">
#     45,193
#    </td>
#    <td>
#     76.5
#    </td>
#    <td align="center">
#     1639
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Barre,_Massachusetts" title="Barre, Massachusetts">
#      Barre
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     5,398
#    </td>
#    <td>
#     44.6
#    </td>
#    <td align="center">
#     1774
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Becket,_Massachusetts" title="Becket, Massachusetts">
#      Becket
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,779
#    </td>
#    <td>
#     47.8
#    </td>
#    <td align="center">
#     1765
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Bedford,_Massachusetts" title="Bedford, Massachusetts">
#      Bedford
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     13,320
#    </td>
#    <td>
#     13.9
#    </td>
#    <td align="center">
#     1729
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Belchertown,_Massachusetts" title="Belchertown, Massachusetts">
#      Belchertown
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     14,649
#    </td>
#    <td>
#     55.4
#    </td>
#    <td align="center">
#     1761
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Bellingham,_Massachusetts" title="Bellingham, Massachusetts">
#      Bellingham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     16,332
#    </td>
#    <td>
#     19.0
#    </td>
#    <td align="center">
#     1719
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Belmont,_Massachusetts" title="Belmont, Massachusetts">
#      Belmont
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     24,729
#    </td>
#    <td>
#     4.7
#    </td>
#    <td align="center">
#     1859
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Berkley,_Massachusetts" title="Berkley, Massachusetts">
#      Berkley
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,411
#    </td>
#    <td>
#     17.4
#    </td>
#    <td align="center">
#     1735
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Berlin,_Massachusetts" title="Berlin, Massachusetts">
#      Berlin
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,866
#    </td>
#    <td>
#     13.1
#    </td>
#    <td align="center">
#     1812
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Bernardston,_Massachusetts" title="Bernardston, Massachusetts">
#      Bernardston
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,129
#    </td>
#    <td>
#     23.4
#    </td>
#    <td align="center">
#     1762
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Beverly,_Massachusetts" title="Beverly, Massachusetts">
#      Beverly
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     39,502
#    </td>
#    <td>
#     22.6
#    </td>
#    <td align="center">
#     1668
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Billerica,_Massachusetts" title="Billerica, Massachusetts">
#      Billerica
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     40,243
#    </td>
#    <td>
#     26.4
#    </td>
#    <td align="center">
#     1655
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Blackstone,_Massachusetts" title="Blackstone, Massachusetts">
#      Blackstone
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     9,026
#    </td>
#    <td>
#     11.2
#    </td>
#    <td align="center">
#     1845
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Blandford,_Massachusetts" title="Blandford, Massachusetts">
#      Blandford
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,233
#    </td>
#    <td>
#     53.4
#    </td>
#    <td align="center">
#     1741
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Bolton,_Massachusetts" title="Bolton, Massachusetts">
#      Bolton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,897
#    </td>
#    <td>
#     20.0
#    </td>
#    <td align="center">
#     1738
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Boston" title="Boston">
#      Boston
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Suffolk
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     617,660
#    </td>
#    <td>
#     89.6
#    </td>
#    <td align="center">
#     1630
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Bourne,_Massachusetts" title="Bourne, Massachusetts">
#      Bourne
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     19,754
#    </td>
#    <td>
#     52.9
#    </td>
#    <td align="center">
#     1884
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Boxborough,_Massachusetts" title="Boxborough, Massachusetts">
#      Boxborough
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,996
#    </td>
#    <td>
#     10.4
#    </td>
#    <td align="center">
#     1835
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Boxford,_Massachusetts" title="Boxford, Massachusetts">
#      Boxford
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,965
#    </td>
#    <td>
#     24.4
#    </td>
#    <td align="center">
#     1685
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Boylston,_Massachusetts" title="Boylston, Massachusetts">
#      Boylston
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,355
#    </td>
#    <td>
#     19.7
#    </td>
#    <td align="center">
#     1785
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Braintree,_Massachusetts" title="Braintree, Massachusetts">
#      Braintree
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-3">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     35,744
#    </td>
#    <td>
#     14.6
#    </td>
#    <td align="center">
#     1640
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Brewster,_Massachusetts" title="Brewster, Massachusetts">
#      Brewster
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     9,820
#    </td>
#    <td>
#     25.4
#    </td>
#    <td align="center">
#     1803
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Bridgewater,_Massachusetts" title="Bridgewater, Massachusetts">
#      Bridgewater
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-4">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Council-manager
#    </td>
#    <td align="right">
#     26,563
#    </td>
#    <td>
#     28.2
#    </td>
#    <td align="center">
#     1656
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Brimfield,_Massachusetts" title="Brimfield, Massachusetts">
#      Brimfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,609
#    </td>
#    <td>
#     35.2
#    </td>
#    <td align="center">
#     1731
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Brockton,_Massachusetts" title="Brockton, Massachusetts">
#      Brockton
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     93,810
#    </td>
#    <td>
#     21.5
#    </td>
#    <td align="center">
#     1821
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Brookfield,_Massachusetts" title="Brookfield, Massachusetts">
#      Brookfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,390
#    </td>
#    <td>
#     16.6
#    </td>
#    <td align="center">
#     1718
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Brookline,_Massachusetts" title="Brookline, Massachusetts">
#      Brookline
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     58,732
#    </td>
#    <td>
#     6.8
#    </td>
#    <td align="center">
#     1705
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Buckland,_Massachusetts" title="Buckland, Massachusetts">
#      Buckland
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,902
#    </td>
#    <td>
#     19.9
#    </td>
#    <td align="center">
#     1779
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Burlington,_Massachusetts" title="Burlington, Massachusetts">
#      Burlington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     24,498
#    </td>
#    <td>
#     11.9
#    </td>
#    <td align="center">
#     1799
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Cambridge,_Massachusetts" title="Cambridge, Massachusetts">
#      Cambridge
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Mayor-manager-council
#    </td>
#    <td align="right">
#     105,162
#    </td>
#    <td>
#     7.1
#    </td>
#    <td align="center">
#     1636
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Canton,_Massachusetts" title="Canton, Massachusetts">
#      Canton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     21,561
#    </td>
#    <td>
#     50.7
#    </td>
#    <td align="center">
#     1797
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Carlisle,_Massachusetts" title="Carlisle, Massachusetts">
#      Carlisle
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,852
#    </td>
#    <td>
#     15.6
#    </td>
#    <td align="center">
#     1780
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Carver,_Massachusetts" title="Carver, Massachusetts">
#      Carver
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     11,509
#    </td>
#    <td>
#     39.7
#    </td>
#    <td align="center">
#     1790
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Charlemont,_Massachusetts" title="Charlemont, Massachusetts">
#      Charlemont
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,266
#    </td>
#    <td>
#     26.4
#    </td>
#    <td align="center">
#     1765
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Charlton,_Massachusetts" title="Charlton, Massachusetts">
#      Charlton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     12,981
#    </td>
#    <td>
#     43.8
#    </td>
#    <td align="center">
#     1755
#     <sup class="reference" id="cite_ref-6">
#      <a href="#cite_note-6">
#       [6]
#      </a>
#     </sup>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chatham,_Massachusetts" title="Chatham, Massachusetts">
#      Chatham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,125
#    </td>
#    <td>
#     24.4
#    </td>
#    <td align="center">
#     1712
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chelmsford,_Massachusetts" title="Chelmsford, Massachusetts">
#      Chelmsford
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     33,802
#    </td>
#    <td>
#     23.2
#    </td>
#    <td align="center">
#     1655
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chelsea,_Massachusetts" title="Chelsea, Massachusetts">
#      Chelsea
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Suffolk
#    </td>
#    <td>
#     Council-manager
#    </td>
#    <td align="right">
#     35,177
#    </td>
#    <td>
#     2.5
#    </td>
#    <td align="center">
#     1739
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Cheshire,_Massachusetts" title="Cheshire, Massachusetts">
#      Cheshire
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,235
#    </td>
#    <td>
#     27.5
#    </td>
#    <td align="center">
#     1793
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chester,_Massachusetts" title="Chester, Massachusetts">
#      Chester
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,337
#    </td>
#    <td>
#     37.2
#    </td>
#    <td align="center">
#     1765
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chesterfield,_Massachusetts" title="Chesterfield, Massachusetts">
#      Chesterfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,222
#    </td>
#    <td>
#     31.2
#    </td>
#    <td align="center">
#     1762
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chicopee,_Massachusetts" title="Chicopee, Massachusetts">
#      Chicopee
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     55,298
#    </td>
#    <td>
#     23.9
#    </td>
#    <td align="center">
#     1848
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Chilmark,_Massachusetts" title="Chilmark, Massachusetts">
#      Chilmark
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Dukes
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     866
#    </td>
#    <td>
#     100.4
#    </td>
#    <td align="center">
#     1714
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Clarksburg,_Massachusetts" title="Clarksburg, Massachusetts">
#      Clarksburg
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,702
#    </td>
#    <td>
#     12.8
#    </td>
#    <td align="center">
#     1798
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Clinton,_Massachusetts" title="Clinton, Massachusetts">
#      Clinton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     13,606
#    </td>
#    <td>
#     7.3
#    </td>
#    <td align="center">
#     1850
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Cohasset,_Massachusetts" title="Cohasset, Massachusetts">
#      Cohasset
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,542
#    </td>
#    <td>
#     31.4
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Colrain,_Massachusetts" title="Colrain, Massachusetts">
#      Colrain
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,671
#    </td>
#    <td>
#     43.4
#    </td>
#    <td align="center">
#     1761
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Concord,_Massachusetts" title="Concord, Massachusetts">
#      Concord
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     17,668
#    </td>
#    <td>
#     25.9
#    </td>
#    <td align="center">
#     1635
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Conway,_Massachusetts" title="Conway, Massachusetts">
#      Conway
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,897
#    </td>
#    <td>
#     37.9
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Cummington,_Massachusetts" title="Cummington, Massachusetts">
#      Cummington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     872
#    </td>
#    <td>
#     23.1
#    </td>
#    <td align="center">
#     1779
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dalton,_Massachusetts" title="Dalton, Massachusetts">
#      Dalton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,756
#    </td>
#    <td>
#     21.9
#    </td>
#    <td align="center">
#     1784
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Danvers,_Massachusetts" title="Danvers, Massachusetts">
#      Danvers
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     26,493
#    </td>
#    <td>
#     14.1
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dartmouth,_Massachusetts" title="Dartmouth, Massachusetts">
#      Dartmouth
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     34,032
#    </td>
#    <td>
#     97.5
#    </td>
#    <td align="center">
#     1664
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dedham,_Massachusetts" title="Dedham, Massachusetts">
#      Dedham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     24,729
#    </td>
#    <td>
#     10.6
#    </td>
#    <td align="center">
#     1636
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Deerfield,_Massachusetts" title="Deerfield, Massachusetts">
#      Deerfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     5,125
#    </td>
#    <td>
#     33.4
#    </td>
#    <td align="center">
#     1677
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dennis,_Massachusetts" title="Dennis, Massachusetts">
#      Dennis
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     14,207
#    </td>
#    <td>
#     22.3
#    </td>
#    <td align="center">
#     1793
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dighton,_Massachusetts" title="Dighton, Massachusetts">
#      Dighton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,086
#    </td>
#    <td>
#     22.6
#    </td>
#    <td align="center">
#     1712
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Douglas,_Massachusetts" title="Douglas, Massachusetts">
#      Douglas
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     8,471
#    </td>
#    <td>
#     37.7
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dover,_Massachusetts" title="Dover, Massachusetts">
#      Dover
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     5,589
#    </td>
#    <td>
#     15.4
#    </td>
#    <td align="center">
#     1836
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dracut,_Massachusetts" title="Dracut, Massachusetts">
#      Dracut
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     29,457
#    </td>
#    <td>
#     21.4
#    </td>
#    <td align="center">
#     1701
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dudley,_Massachusetts" title="Dudley, Massachusetts">
#      Dudley
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     11,390
#    </td>
#    <td>
#     22.1
#    </td>
#    <td align="center">
#     1732
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Dunstable,_Massachusetts" title="Dunstable, Massachusetts">
#      Dunstable
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,179
#    </td>
#    <td>
#     16.7
#    </td>
#    <td align="center">
#     1673
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Duxbury,_Massachusetts" title="Duxbury, Massachusetts">
#      Duxbury
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     15,059
#    </td>
#    <td>
#     37.6
#    </td>
#    <td align="center">
#     1637
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/East_Bridgewater,_Massachusetts" title="East Bridgewater, Massachusetts">
#      East Bridgewater
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     13,794
#    </td>
#    <td>
#     17.5
#    </td>
#    <td align="center">
#     1823
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/East_Brookfield,_Massachusetts" title="East Brookfield, Massachusetts">
#      East Brookfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,183
#    </td>
#    <td>
#     10.4
#    </td>
#    <td align="center">
#     1920
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/East_Longmeadow,_Massachusetts" title="East Longmeadow, Massachusetts">
#      East Longmeadow
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Manager-Council
#    </td>
#    <td align="right">
#     15,720
#    </td>
#    <td>
#     13.0
#    </td>
#    <td align="center">
#     1894
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Eastham,_Massachusetts" title="Eastham, Massachusetts">
#      Eastham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,956
#    </td>
#    <td>
#     25.7
#    </td>
#    <td align="center">
#     1646
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Easthampton,_Massachusetts" title="Easthampton, Massachusetts">
#      Easthampton
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     16,053
#    </td>
#    <td>
#     13.6
#    </td>
#    <td align="center">
#     1809
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Easton,_Massachusetts" title="Easton, Massachusetts">
#      Easton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     23,112
#    </td>
#    <td>
#     29.2
#    </td>
#    <td align="center">
#     1725
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Edgartown,_Massachusetts" title="Edgartown, Massachusetts">
#      Edgartown
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Dukes
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,067
#    </td>
#    <td>
#     122.7
#    </td>
#    <td align="center">
#     1671
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Egremont,_Massachusetts" title="Egremont, Massachusetts">
#      Egremont
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,225
#    </td>
#    <td>
#     18.9
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Erving,_Massachusetts" title="Erving, Massachusetts">
#      Erving
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,800
#    </td>
#    <td>
#     14.4
#    </td>
#    <td align="center">
#     1838
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Essex,_Massachusetts" title="Essex, Massachusetts">
#      Essex
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,504
#    </td>
#    <td>
#     15.9
#    </td>
#    <td align="center">
#     1819
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Everett,_Massachusetts" title="Everett, Massachusetts">
#      Everett
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     41,667
#    </td>
#    <td>
#     3.7
#    </td>
#    <td align="center">
#     1870
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Fairhaven,_Massachusetts" title="Fairhaven, Massachusetts">
#      Fairhaven
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     15,873
#    </td>
#    <td>
#     14.1
#    </td>
#    <td align="center">
#     1812
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Fall_River,_Massachusetts" title="Fall River, Massachusetts">
#      Fall River
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     88,857
#    </td>
#    <td>
#     40.2
#    </td>
#    <td align="center">
#     1803
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Falmouth,_Massachusetts" title="Falmouth, Massachusetts">
#      Falmouth
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     31,531
#    </td>
#    <td>
#     54.4
#    </td>
#    <td align="center">
#     1686
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Fitchburg,_Massachusetts" title="Fitchburg, Massachusetts">
#      Fitchburg
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     40,318
#    </td>
#    <td>
#     28.1
#    </td>
#    <td align="center">
#     1764
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Florida,_Massachusetts" title="Florida, Massachusetts">
#      Florida
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     752
#    </td>
#    <td>
#     24.6
#    </td>
#    <td align="center">
#     1805
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Foxborough,_Massachusetts" title="Foxborough, Massachusetts">
#      Foxborough
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     16,865
#    </td>
#    <td>
#     20.9
#    </td>
#    <td align="center">
#     1778
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Framingham,_Massachusetts" title="Framingham, Massachusetts">
#      Framingham
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     68,318
#    </td>
#    <td>
#     26.5
#    </td>
#    <td align="center">
#     1700
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Franklin,_Massachusetts" title="Franklin, Massachusetts">
#      Franklin
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-5">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Council-administrator
#    </td>
#    <td align="right">
#     31,635
#    </td>
#    <td>
#     27.0
#    </td>
#    <td align="center">
#     1778
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Freetown,_Massachusetts" title="Freetown, Massachusetts">
#      Freetown
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     8,870
#    </td>
#    <td>
#     38.3
#    </td>
#    <td align="center">
#     1683
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Gardner,_Massachusetts" title="Gardner, Massachusetts">
#      Gardner
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     20,228
#    </td>
#    <td>
#     23.0
#    </td>
#    <td align="center">
#     1785
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Georgetown,_Massachusetts" title="Georgetown, Massachusetts">
#      Georgetown
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     8,183
#    </td>
#    <td>
#     13.2
#    </td>
#    <td align="center">
#     1838
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Gill,_Massachusetts" title="Gill, Massachusetts">
#      Gill
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,500
#    </td>
#    <td>
#     14.8
#    </td>
#    <td align="center">
#     1793
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Gloucester,_Massachusetts" title="Gloucester, Massachusetts">
#      Gloucester
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     28,789
#    </td>
#    <td>
#     41.5
#    </td>
#    <td align="center">
#     1623
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Goshen,_Massachusetts" title="Goshen, Massachusetts">
#      Goshen
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,054
#    </td>
#    <td>
#     17.7
#    </td>
#    <td align="center">
#     1781
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Gosnold,_Massachusetts" title="Gosnold, Massachusetts">
#      Gosnold
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Dukes
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     75
#    </td>
#    <td>
#     140.2
#    </td>
#    <td align="center">
#     1864
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Grafton,_Massachusetts" title="Grafton, Massachusetts">
#      Grafton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     17,765
#    </td>
#    <td>
#     23.3
#    </td>
#    <td align="center">
#     1735
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Granby,_Massachusetts" title="Granby, Massachusetts">
#      Granby
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,240
#    </td>
#    <td>
#     28.1
#    </td>
#    <td align="center">
#     1768
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Granville,_Massachusetts" title="Granville, Massachusetts">
#      Granville
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,566
#    </td>
#    <td>
#     43.0
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Great_Barrington,_Massachusetts" title="Great Barrington, Massachusetts">
#      Great Barrington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,104
#    </td>
#    <td>
#     45.8
#    </td>
#    <td align="center">
#     1761
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Greenfield,_Massachusetts" title="Greenfield, Massachusetts">
#      Greenfield
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-6">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     17,456
#    </td>
#    <td>
#     21.4
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Groton,_Massachusetts" title="Groton, Massachusetts">
#      Groton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     10,646
#    </td>
#    <td>
#     33.7
#    </td>
#    <td align="center">
#     1655
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Groveland,_Massachusetts" title="Groveland, Massachusetts">
#      Groveland
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,459
#    </td>
#    <td>
#     9.4
#    </td>
#    <td align="center">
#     1850
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hadley,_Massachusetts" title="Hadley, Massachusetts">
#      Hadley
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     5,250
#    </td>
#    <td>
#     24.6
#    </td>
#    <td align="center">
#     1661
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Halifax,_Massachusetts" title="Halifax, Massachusetts">
#      Halifax
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,518
#    </td>
#    <td>
#     17.3
#    </td>
#    <td align="center">
#     1734
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hamilton,_Massachusetts" title="Hamilton, Massachusetts">
#      Hamilton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,764
#    </td>
#    <td>
#     14.9
#    </td>
#    <td align="center">
#     1793
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hampden,_Massachusetts" title="Hampden, Massachusetts">
#      Hampden
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     5,139
#    </td>
#    <td>
#     19.7
#    </td>
#    <td align="center">
#     1878
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hancock,_Massachusetts" title="Hancock, Massachusetts">
#      Hancock
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     717
#    </td>
#    <td>
#     35.8
#    </td>
#    <td align="center">
#     1776
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hanover,_Massachusetts" title="Hanover, Massachusetts">
#      Hanover
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     13,879
#    </td>
#    <td>
#     15.7
#    </td>
#    <td align="center">
#     1727
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hanson,_Massachusetts" title="Hanson, Massachusetts">
#      Hanson
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     10,209
#    </td>
#    <td>
#     15.7
#    </td>
#    <td align="center">
#     1820
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hardwick,_Massachusetts" title="Hardwick, Massachusetts">
#      Hardwick
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,990
#    </td>
#    <td>
#     40.8
#    </td>
#    <td align="center">
#     1739
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Harvard,_Massachusetts" title="Harvard, Massachusetts">
#      Harvard
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,520
#    </td>
#    <td>
#     27.0
#    </td>
#    <td align="center">
#     1732
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Harwich,_Massachusetts" title="Harwich, Massachusetts">
#      Harwich
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     12,243
#    </td>
#    <td>
#     33.1
#    </td>
#    <td align="center">
#     1694
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hatfield,_Massachusetts" title="Hatfield, Massachusetts">
#      Hatfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,279
#    </td>
#    <td>
#     16.8
#    </td>
#    <td align="center">
#     1670
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Haverhill,_Massachusetts" title="Haverhill, Massachusetts">
#      Haverhill
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     60,879
#    </td>
#    <td>
#     35.7
#    </td>
#    <td align="center">
#     1641
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hawley,_Massachusetts" title="Hawley, Massachusetts">
#      Hawley
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     337
#    </td>
#    <td>
#     30.9
#    </td>
#    <td align="center">
#     1792
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Heath,_Massachusetts" title="Heath, Massachusetts">
#      Heath
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     706
#    </td>
#    <td>
#     24.9
#    </td>
#    <td align="center">
#     1785
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hingham,_Massachusetts" title="Hingham, Massachusetts">
#      Hingham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     22,157
#    </td>
#    <td>
#     26.3
#    </td>
#    <td align="center">
#     1635
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hinsdale,_Massachusetts" title="Hinsdale, Massachusetts">
#      Hinsdale
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,032
#    </td>
#    <td>
#     21.7
#    </td>
#    <td align="center">
#     1804
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Holbrook,_Massachusetts" title="Holbrook, Massachusetts">
#      Holbrook
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     10,791
#    </td>
#    <td>
#     7.4
#    </td>
#    <td align="center">
#     1872
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Holden,_Massachusetts" title="Holden, Massachusetts">
#      Holden
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     17,346
#    </td>
#    <td>
#     36.2
#    </td>
#    <td align="center">
#     1741
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Holland,_Massachusetts" title="Holland, Massachusetts">
#      Holland
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,481
#    </td>
#    <td>
#     13.1
#    </td>
#    <td align="center">
#     1835
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Holliston,_Massachusetts" title="Holliston, Massachusetts">
#      Holliston
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     13,547
#    </td>
#    <td>
#     19.0
#    </td>
#    <td align="center">
#     1724
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Holyoke,_Massachusetts" title="Holyoke, Massachusetts">
#      Holyoke
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     39,880
#    </td>
#    <td>
#     22.8
#    </td>
#    <td align="center">
#     1850
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Hopedale,_Massachusetts" title="Hopedale, Massachusetts">
#      Hopedale
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
# ...
#      Wales
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,838
#    </td>
#    <td>
#     15.9
#    </td>
#    <td align="center">
#     1762
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Walpole,_Massachusetts" title="Walpole, Massachusetts">
#      Walpole
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     24,070
#    </td>
#    <td>
#     21.0
#    </td>
#    <td align="center">
#     1724
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Waltham,_Massachusetts" title="Waltham, Massachusetts">
#      Waltham
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     60,632
#    </td>
#    <td>
#     13.8
#    </td>
#    <td align="center">
#     1738
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Ware,_Massachusetts" title="Ware, Massachusetts">
#      Ware
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     9,872
#    </td>
#    <td>
#     40.0
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wareham,_Massachusetts" title="Wareham, Massachusetts">
#      Wareham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     21,822
#    </td>
#    <td>
#     46.3
#    </td>
#    <td align="center">
#     1739
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Warren,_Massachusetts" title="Warren, Massachusetts">
#      Warren
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     5,135
#    </td>
#    <td>
#     27.6
#    </td>
#    <td align="center">
#     1742
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Warwick,_Massachusetts" title="Warwick, Massachusetts">
#      Warwick
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     780
#    </td>
#    <td>
#     37.6
#    </td>
#    <td align="center">
#     1763
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Washington,_Massachusetts" title="Washington, Massachusetts">
#      Washington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     538
#    </td>
#    <td>
#     38.8
#    </td>
#    <td align="center">
#     1777
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Watertown,_Massachusetts" title="Watertown, Massachusetts">
#      Watertown
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-11">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Council-manager
#    </td>
#    <td align="right">
#     31,915
#    </td>
#    <td>
#     4.1
#    </td>
#    <td align="center">
#     1630
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wayland,_Massachusetts" title="Wayland, Massachusetts">
#      Wayland
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     12,994
#    </td>
#    <td>
#     15.9
#    </td>
#    <td align="center">
#     1780
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Webster,_Massachusetts" title="Webster, Massachusetts">
#      Webster
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     16,767
#    </td>
#    <td>
#     14.5
#    </td>
#    <td align="center">
#     1832
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wellesley,_Massachusetts" title="Wellesley, Massachusetts">
#      Wellesley
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     27,982
#    </td>
#    <td>
#     10.5
#    </td>
#    <td align="center">
#     1881
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wellfleet,_Massachusetts" title="Wellfleet, Massachusetts">
#      Wellfleet
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,750
#    </td>
#    <td>
#     35.4
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wendell,_Massachusetts" title="Wendell, Massachusetts">
#      Wendell
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     848
#    </td>
#    <td>
#     32.2
#    </td>
#    <td align="center">
#     1781
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wenham,_Massachusetts" title="Wenham, Massachusetts">
#      Wenham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,875
#    </td>
#    <td>
#     8.1
#    </td>
#    <td align="center">
#     1643
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Boylston,_Massachusetts" title="West Boylston, Massachusetts">
#      West Boylston
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,669
#    </td>
#    <td>
#     13.8
#    </td>
#    <td align="center">
#     1808
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Bridgewater,_Massachusetts" title="West Bridgewater, Massachusetts">
#      West Bridgewater
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     6,916
#    </td>
#    <td>
#     15.7
#    </td>
#    <td align="center">
#     1822
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Brookfield,_Massachusetts" title="West Brookfield, Massachusetts">
#      West Brookfield
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     3,701
#    </td>
#    <td>
#     21.1
#    </td>
#    <td align="center">
#     1848
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Newbury,_Massachusetts" title="West Newbury, Massachusetts">
#      West Newbury
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Essex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     4,235
#    </td>
#    <td>
#     14.7
#    </td>
#    <td align="center">
#     1819
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Springfield,_Massachusetts" title="West Springfield, Massachusetts">
#      West Springfield
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-12">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     28,391
#    </td>
#    <td>
#     17.5
#    </td>
#    <td align="center">
#     1774
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Stockbridge,_Massachusetts" title="West Stockbridge, Massachusetts">
#      West Stockbridge
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,306
#    </td>
#    <td>
#     18.7
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/West_Tisbury,_Massachusetts" title="West Tisbury, Massachusetts">
#      West Tisbury
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Dukes
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,740
#    </td>
#    <td>
#     41.8
#    </td>
#    <td align="center">
#     1892
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westborough,_Massachusetts" title="Westborough, Massachusetts">
#      Westborough
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     18,272
#    </td>
#    <td>
#     21.6
#    </td>
#    <td align="center">
#     1717
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westfield,_Massachusetts" title="Westfield, Massachusetts">
#      Westfield
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     41,094
#    </td>
#    <td>
#     47.3
#    </td>
#    <td align="center">
#     1669
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westford,_Massachusetts" title="Westford, Massachusetts">
#      Westford
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     21,951
#    </td>
#    <td>
#     31.3
#    </td>
#    <td align="center">
#     1729
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westhampton,_Massachusetts" title="Westhampton, Massachusetts">
#      Westhampton
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,607
#    </td>
#    <td>
#     27.4
#    </td>
#    <td align="center">
#     1778
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westminster,_Massachusetts" title="Westminster, Massachusetts">
#      Westminster
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,277
#    </td>
#    <td>
#     37.3
#    </td>
#    <td align="center">
#     1770
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Weston,_Massachusetts" title="Weston, Massachusetts">
#      Weston
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     11,261
#    </td>
#    <td>
#     17.3
#    </td>
#    <td align="center">
#     1713
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westport,_Massachusetts" title="Westport, Massachusetts">
#      Westport
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Bristol
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     15,532
#    </td>
#    <td>
#     64.4
#    </td>
#    <td align="center">
#     1787
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Westwood,_Massachusetts" title="Westwood, Massachusetts">
#      Westwood
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     14,618
#    </td>
#    <td>
#     11.1
#    </td>
#    <td align="center">
#     1897
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Weymouth,_Massachusetts" title="Weymouth, Massachusetts">
#      Weymouth
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-13">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Mayor-council
#    </td>
#    <td align="right">
#     53,743
#    </td>
#    <td>
#     21.6
#    </td>
#    <td align="center">
#     1635
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Whately,_Massachusetts" title="Whately, Massachusetts">
#      Whately
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Franklin
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,496
#    </td>
#    <td>
#     20.7
#    </td>
#    <td align="center">
#     1771
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Whitman,_Massachusetts" title="Whitman, Massachusetts">
#      Whitman
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Plymouth
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     14,489
#    </td>
#    <td>
#     7.1
#    </td>
#    <td align="center">
#     1875
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wilbraham,_Massachusetts" title="Wilbraham, Massachusetts">
#      Wilbraham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampden
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     14,219
#    </td>
#    <td>
#     22.4
#    </td>
#    <td align="center">
#     1763
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Williamsburg,_Massachusetts" title="Williamsburg, Massachusetts">
#      Williamsburg
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     2,482
#    </td>
#    <td>
#     25.7
#    </td>
#    <td align="center">
#     1775
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Williamstown,_Massachusetts" title="Williamstown, Massachusetts">
#      Williamstown
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     7,754
#    </td>
#    <td>
#     46.9
#    </td>
#    <td align="center">
#     1765
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wilmington,_Massachusetts" title="Wilmington, Massachusetts">
#      Wilmington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     22,325
#    </td>
#    <td>
#     17.2
#    </td>
#    <td align="center">
#     1730
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Winchendon,_Massachusetts" title="Winchendon, Massachusetts">
#      Winchendon
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     10,300
#    </td>
#    <td>
#     44.1
#    </td>
#    <td align="center">
#     1764
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Winchester,_Massachusetts" title="Winchester, Massachusetts">
#      Winchester
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Representative town meeting
#    </td>
#    <td align="right">
#     21,374
#    </td>
#    <td>
#     6.3
#    </td>
#    <td align="center">
#     1850
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Windsor,_Massachusetts" title="Windsor, Massachusetts">
#      Windsor
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Berkshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     899
#    </td>
#    <td>
#     35.2
#    </td>
#    <td align="center">
#     1771
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Winthrop,_Massachusetts" title="Winthrop, Massachusetts">
#      Winthrop
#     </a>
#    </td>
#    <td>
#     City
#     <sup class="reference" id="cite_ref-TC_4-14">
#      <a href="#cite_note-TC-4">
#       [4]
#      </a>
#     </sup>
#    </td>
#    <td>
#     Suffolk
#    </td>
#    <td>
#     Council-manager
#    </td>
#    <td align="right">
#     17,497
#    </td>
#    <td>
#     8.3
#    </td>
#    <td align="center">
#     1852
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Woburn,_Massachusetts" title="Woburn, Massachusetts">
#      Woburn
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Middlesex
#    </td>
#    <td>
#     Mayor-aldermen
#    </td>
#    <td align="right">
#     38,120
#    </td>
#    <td>
#     12.9
#    </td>
#    <td align="center">
#     1642
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Worcester,_Massachusetts" title="Worcester, Massachusetts">
#      Worcester
#     </a>
#    </td>
#    <td>
#     City
#    </td>
#    <td>
#     Worcester
#    </td>
#    <td>
#     Mayor-manager-council
#    </td>
#    <td align="right">
#     181,045
#    </td>
#    <td>
#     38.5
#    </td>
#    <td align="center">
#     1684
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Worthington,_Massachusetts" title="Worthington, Massachusetts">
#      Worthington
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Hampshire
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     1,156
#    </td>
#    <td>
#     32.1
#    </td>
#    <td align="center">
#     1768
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Wrentham,_Massachusetts" title="Wrentham, Massachusetts">
#      Wrentham
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Norfolk
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     10,955
#    </td>
#    <td>
#     22.9
#    </td>
#    <td align="center">
#     1673
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a href="/wiki/Yarmouth,_Massachusetts" title="Yarmouth, Massachusetts">
#      Yarmouth
#     </a>
#    </td>
#    <td>
#     Town
#    </td>
#    <td>
#     Barnstable
#    </td>
#    <td>
#     Open town meeting
#    </td>
#    <td align="right">
#     23,793
#    </td>
#    <td>
#     28.2
#    </td>
#    <td align="center">
#     1639
#    </td>
#   </tr>
#  </tbody>
# </table>

# %% [markdown]
# Excellent! Now we just need to pull out the data from the rows and columns of that table. Notice that there are 6 columns, each `row` is contained in a `<tr>` element (which stands for `table row`), and inside each row there is a `<td>` element for each entry. That's what we want, so let's loop through them:

# %%
import re # Might need to do some pattern matching with regular expressions

# Open a file to store the data
f = open('output.csv', 'w')
 
# First grab the headers
t_headers = []
for th in table.find_all("th"):
        # remove any references in square brackets and extra spaces from left and right
        t_headers.append(re.sub('\[.*?\]', '', th.text).strip())

f.write(",".join(t_headers) + "\n")
    
# Loop over each row in the table
for row in table.findAll("tr"):
    
    # Find all the cells in the row
    cells = row.findAll("td")
    
    # If the row is complete (i.e. there are 7 cells)
    #    assign the value in each cell to the appropriate variable.
    if len(cells) == 7:
        
        Municipality = cells[0].find(text = True)
        
        Type = cells[1].find(text = True)
        
        County = cells[2].find(text = True)
        
        Form_of_government = cells[3].find(text = True)
        
        # This cell sometimes has a comma in it, let's get rid opf that while we're here
        Population = cells[4].find(text = True).replace(',', '')
        
        Area = cells[5].find(text = True)
        
        Year_est = cells[6].find(text = True)
 
        # Concatenate all the cells together, separated by commas
        line = Municipality  + "," + Type + "," + County + "," + Form_of_government + "," + Population + "," + Area + "," + Year_est + "\n"
        
        # Append the line to the file
        f.write(line)
        
# Clean up when we're done
f.close()

# %% [markdown]
# ## And there you have it! You're ready to wrangle some data of your own.
